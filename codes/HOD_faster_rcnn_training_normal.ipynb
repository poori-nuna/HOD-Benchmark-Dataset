# %% [markdown]
# Code Author: Ha Eungyeom (eungyeom_ha@yonsei.ac.kr)
#  This code is developed for training and evaluating a Faster-RCNN model on the HOD datasetCases

# %% [markdown]
# ### Training Code - Normal Cases
# #### Paper Section: 3.1 Environment Setup

# %%
# Displaying the current working directory
# !pwd
# Out:
# /home/oks/people/egha/ob_code_faster_rcnn

# %%
# Changing to the parent directory
cd ..
# Out:
# /home/oks/people/egha

# %%
# Installing necessary library for file downloading
# !pip install down

# Downloading the dataset using Google Drive link
# !gdown --id 1NEQWK062dMREwDSbHOPPMx-99iUVebrN -O faster_rcnn_dataset.zip

# Creating a directory for the dataset and extracting the dataset there
# !mkdir faster_rcnn_data
# !unzip faster_rcnn_dataset.zip -d faster_rcnn_data
# Out:
# '\n!pip install down\n\n!gdown --id 1NEQWK062dMREwDSbHOPPMx-99iUVebrN -O faster_rcnn_dataset.zip\n!mkdir faster_rcnn_data\n!unzip faster_rcnn_dataset.zip -d faster_rcnn_data\n'

# %%
# !pwd
# Out:
# /home/oks/people/egha

# %%
# Setting up the name for normal case training
name = '/rcnn_normal/'

# %%
# Importing required libraries
import os
import xml.etree.ElementTree as ET

# Specifying the directory path for annotations
directory_path = './faster_rcnn_data' + name  + 'Annotations/'

# %% [markdown]
# ### Function to remove spaces from tags in XML files
# #### Paper Section: 3.2 Data Preprocessing

# %%
def remove_spaces_from_tags(dir_path):
    for filename in os.listdir(dir_path):
        if filename.lower().endswith('.xml'):
            filepath = os.path.join(dir_path, filename)
            
            # Parsing the XML file
            tree = ET.parse(filepath)
            root = tree.getroot()

            # Removing spaces from <filename> and <path> tags
            for tag in ['filename', 'path']:
                element = root.find(tag)
                if element is not None:
                    # 공백 제거
                    element.text = element.text.replace(" ", "")
            
            # Saving the changes back to the XML file
            tree.write(filepath)
            print(f"Changed file: {filename}")

# Executing the function to preprocess XML annotations
remove_spaces_from_tags(directory_path)

# %% [markdown]
# ### Installation of MMDetection
# #### Paper Section: 3.3 Framework Preparation
# Detailed steps and explanations for setting up MMDetection, including addressing version compatibilities.
# .

# %%
# Checking the version of PyTorch
import torch
print(torch.__version__)
# Out:
# 1.13.0+cu116

# %%
# Downgrading PyTorch to 1.13.0+cu116 for compatibility with MMDetection
# !pip install torch==1.13.0+cu116 torchvision==0.14.0+cu116 --extra-index-url https://download.pytorch.org/whl/cu116
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu116
# Requirement already satisfied: torch==1.13.0+cu116 in /home/oks/anaconda3/lib/python3.9/site-packages (1.13.0+cu116)
# Requirement already satisfied: torchvision==0.14.0+cu116 in /home/oks/anaconda3/lib/python3.9/site-packages (0.14.0+cu116)
# Requirement already satisfied: typing-extensions in /home/oks/anaconda3/lib/python3.9/site-packages (from torch==1.13.0+cu116) (4.4.0)
# Requirement already satisfied: numpy in /home/oks/anaconda3/lib/python3.9/site-packages (from torchvision==0.14.0+cu116) (1.25.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/oks/anaconda3/lib/python3.9/site-packages (from torchvision==0.14.0+cu116) (9.4.0)
# Requirement already satisfied: requests in /home/oks/anaconda3/lib/python3.9/site-packages (from torchvision==0.14.0+cu116) (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/oks/anaconda3/lib/python3.9/site-packages (from requests->torchvision==0.14.0+cu116) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /home/oks/anaconda3/lib/python3.9/site-packages (from requests->torchvision==0.14.0+cu116) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/oks/anaconda3/lib/python3.9/site-packages (from requests->torchvision==0.14.0+cu116) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/oks/anaconda3/lib/python3.9/site-packages (from requests->torchvision==0.14.0+cu116) (2.0.4)
#
# [notice] A new release of pip is available: 23.0 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Installing mmcv-full
# !pip install mmcv-full -f https://download.openmmlab.com/mmcv/dist/cu116/torch1.13/index.html
# Out:
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu116/torch1.13/index.html
# Requirement already satisfied: mmcv-full in /home/oks/anaconda3/lib/python3.9/site-packages (1.7.1)
# Requirement already satisfied: Pillow in /home/oks/anaconda3/lib/python3.9/site-packages (from mmcv-full) (9.4.0)
# Requirement already satisfied: pyyaml in /home/oks/anaconda3/lib/python3.9/site-packages (from mmcv-full) (6.0)
# Requirement already satisfied: addict in /home/oks/anaconda3/lib/python3.9/site-packages (from mmcv-full) (2.4.0)
# Requirement already satisfied: packaging in /home/oks/anaconda3/lib/python3.9/site-packages (from mmcv-full) (23.0)
# Requirement already satisfied: opencv-python>=3 in /home/oks/anaconda3/lib/python3.9/site-packages (from mmcv-full) (4.8.0.76)
# Requirement already satisfied: numpy in /home/oks/anaconda3/lib/python3.9/site-packages (from mmcv-full) (1.25.1)
# Requirement already satisfied: yapf in /home/oks/anaconda3/lib/python3.9/site-packages (from mmcv-full) (0.40.1)
# Requirement already satisfied: tomli>=2.0.1 in /home/oks/anaconda3/lib/python3.9/site-packages (from yapf->mmcv-full) (2.0.1)
# Requirement already satisfied: platformdirs>=3.5.1 in /home/oks/anaconda3/lib/python3.9/site-packages (from yapf->mmcv-full) (3.10.0)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /home/oks/anaconda3/lib/python3.9/site-packages (from yapf->mmcv-full) (6.8.0)
# Requirement already satisfied: zipp>=0.5 in /home/oks/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=6.6.0->yapf->mmcv-full) (3.11.0)
#
# [notice] A new release of pip is available: 23.0 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Cloning and installing MMDetection (version 2.x)
# !git clone --branch 2.x https://github.com/open-mmlab/mmdetection.git
# !cd mmdetection; python setup.py install
# Out:
# fatal: 대상 경로가('mmdetection') 이미 있고 빈 디렉터리가 아닙니다.
# running install
# /home/oks/anaconda3/lib/python3.9/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /home/oks/anaconda3/lib/python3.9/site-packages/setuptools/command/easy_install.py:144: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# running bdist_egg
# running egg_info
# writing mmdet.egg-info/PKG-INFO
# writing dependency_links to mmdet.egg-info/dependency_links.txt
# writing requirements to mmdet.egg-info/requires.txt
# writing top-level names to mmdet.egg-info/top_level.txt
# reading manifest file 'mmdet.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching 'mmdet/VERSION'
# warning: no files found matching 'mmdet/.mim/model-index.yml'
# warning: no files found matching 'mmdet/.mim/demo/*/*'
# warning: no files found matching '*.py' under directory 'mmdet/.mim/configs'
# warning: no files found matching '*.yml' under directory 'mmdet/.mim/configs'
# warning: no files found matching '*.sh' under directory 'mmdet/.mim/tools'
# warning: no files found matching '*.py' under directory 'mmdet/.mim/tools'
# adding license file 'LICENSE'
# writing manifest file 'mmdet.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/mmdet
# copying build/lib/mmdet/__init__.py -> build/bdist.linux-x86_64/egg/mmdet
# creating build/bdist.linux-x86_64/egg/mmdet/datasets
# copying build/lib/mmdet/datasets/coco_occluded.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# copying build/lib/mmdet/datasets/coco_panoptic.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# copying build/lib/mmdet/datasets/xml_style.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# copying build/lib/mmdet/datasets/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# copying build/lib/mmdet/datasets/voc.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# creating build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines
# copying build/lib/mmdet/datasets/pipelines/test_time_aug.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines
# copying build/lib/mmdet/datasets/pipelines/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines
# copying build/lib/mmdet/datasets/pipelines/transforms.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines
# copying build/lib/mmdet/datasets/pipelines/compose.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines
# copying build/lib/mmdet/datasets/pipelines/loading.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines
# copying build/lib/mmdet/datasets/pipelines/instaboost.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines
# copying build/lib/mmdet/datasets/pipelines/formating.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines
# copying build/lib/mmdet/datasets/pipelines/auto_augment.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines
# copying build/lib/mmdet/datasets/pipelines/formatting.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines
# copying build/lib/mmdet/datasets/cityscapes.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# copying build/lib/mmdet/datasets/dataset_wrappers.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# copying build/lib/mmdet/datasets/openimages.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# creating build/bdist.linux-x86_64/egg/mmdet/datasets/api_wrappers
# copying build/lib/mmdet/datasets/api_wrappers/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/api_wrappers
# copying build/lib/mmdet/datasets/api_wrappers/coco_api.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/api_wrappers
# copying build/lib/mmdet/datasets/api_wrappers/panoptic_evaluation.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/api_wrappers
# copying build/lib/mmdet/datasets/coco.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# copying build/lib/mmdet/datasets/lvis.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# copying build/lib/mmdet/datasets/utils.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# copying build/lib/mmdet/datasets/custom.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# copying build/lib/mmdet/datasets/builder.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# copying build/lib/mmdet/datasets/wider_face.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# creating build/bdist.linux-x86_64/egg/mmdet/datasets/samplers
# copying build/lib/mmdet/datasets/samplers/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/samplers
# copying build/lib/mmdet/datasets/samplers/class_aware_sampler.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/samplers
# copying build/lib/mmdet/datasets/samplers/distributed_sampler.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/samplers
# copying build/lib/mmdet/datasets/samplers/group_sampler.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/samplers
# copying build/lib/mmdet/datasets/samplers/infinite_sampler.py -> build/bdist.linux-x86_64/egg/mmdet/datasets/samplers
# copying build/lib/mmdet/datasets/objects365.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# copying build/lib/mmdet/datasets/deepfashion.py -> build/bdist.linux-x86_64/egg/mmdet/datasets
# creating build/bdist.linux-x86_64/egg/mmdet/models
# copying build/lib/mmdet/models/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models
# creating build/bdist.linux-x86_64/egg/mmdet/models/plugins
# copying build/lib/mmdet/models/plugins/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/plugins
# copying build/lib/mmdet/models/plugins/dropblock.py -> build/bdist.linux-x86_64/egg/mmdet/models/plugins
# copying build/lib/mmdet/models/plugins/pixel_decoder.py -> build/bdist.linux-x86_64/egg/mmdet/models/plugins
# copying build/lib/mmdet/models/plugins/msdeformattn_pixel_decoder.py -> build/bdist.linux-x86_64/egg/mmdet/models/plugins
# creating build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/iou_loss.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/ghm_loss.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/mse_loss.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/gfocal_loss.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/balanced_l1_loss.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/utils.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/cross_entropy_loss.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/gaussian_focal_loss.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/focal_loss.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/varifocal_loss.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/accuracy.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/pisa_loss.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/ae_loss.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/seesaw_loss.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/kd_loss.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/smooth_l1_loss.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# copying build/lib/mmdet/models/losses/dice_loss.py -> build/bdist.linux-x86_64/egg/mmdet/models/losses
# creating build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/brick_wrappers.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/se_layer.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/misc.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/transformer.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/normed_predictor.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/positional_encoding.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/res_layer.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/ckpt_convert.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/make_divisible.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/point_sample.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/conv_upsample.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/builder.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/panoptic_gt_processing.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/gaussian_target.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/inverted_residual.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# copying build/lib/mmdet/models/utils/csp_layer.py -> build/bdist.linux-x86_64/egg/mmdet/models/utils
# creating build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/hourglass.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/hrnet.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/resnext.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/swin.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/resnet.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/trident_resnet.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/mobilenet_v2.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/resnest.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/darknet.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/efficientnet.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/detectors_resnext.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/detectors_resnet.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/pvt.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/regnet.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/csp_darknet.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/ssd_vgg.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# copying build/lib/mmdet/models/backbones/res2net.py -> build/bdist.linux-x86_64/egg/mmdet/models/backbones
# creating build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/fpn.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/pafpn.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/yolo_neck.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/fpg.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/dilated_encoder.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/ssd_neck.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/yolox_pafpn.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/nasfcos_fpn.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/dyhead.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/fpn_carafe.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/rfp.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/ct_resnet_neck.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/nas_fpn.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/hrfpn.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/bfp.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# copying build/lib/mmdet/models/necks/channel_mapper.py -> build/bdist.linux-x86_64/egg/mmdet/models/necks
# creating build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/panoptic_two_stage_segmentor.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/trident_faster_rcnn.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/fovea.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/base.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/yolo.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/nasfcos.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/single_stage_instance_seg.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/solo.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/autoassign.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/mask_rcnn.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/yolact.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/yolox.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/kd_one_stage.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/maskformer.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/faster_rcnn.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/point_rend.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/reppoints_detector.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/detr.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/ddod.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/fast_rcnn.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/scnet.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/mask2former.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/lad.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/panoptic_fpn.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/single_stage.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/centernet.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/grid_rcnn.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/rpn.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/tood.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/deformable_detr.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/paa.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/yolof.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/cascade_rcnn.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/gfl.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/retinanet.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/mask_scoring_rcnn.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/vfnet.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/two_stage.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/cornernet.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/fcos.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/queryinst.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/atss.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/htc.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/solov2.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/sparse_rcnn.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# copying build/lib/mmdet/models/detectors/fsaf.py -> build/bdist.linux-x86_64/egg/mmdet/models/detectors
# creating build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/pisa_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# creating build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/mask_point_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/grid_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/scnet_semantic_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/dynamic_mask_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/global_context_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/maskiou_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/scnet_mask_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/feature_relay_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/htc_mask_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/coarse_mask_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/fused_semantic_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/mask_heads/fcn_mask_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/mask_heads
# copying build/lib/mmdet/models/roi_heads/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/standard_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# creating build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/shared_heads
# copying build/lib/mmdet/models/roi_heads/shared_heads/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/shared_heads
# copying build/lib/mmdet/models/roi_heads/shared_heads/res_layer.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/shared_heads
# creating build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/roi_extractors
# copying build/lib/mmdet/models/roi_heads/roi_extractors/base_roi_extractor.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/roi_extractors
# copying build/lib/mmdet/models/roi_heads/roi_extractors/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/roi_extractors
# copying build/lib/mmdet/models/roi_heads/roi_extractors/generic_roi_extractor.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/roi_extractors
# copying build/lib/mmdet/models/roi_heads/roi_extractors/single_level_roi_extractor.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/roi_extractors
# copying build/lib/mmdet/models/roi_heads/trident_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/double_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# creating build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/bbox_heads
# copying build/lib/mmdet/models/roi_heads/bbox_heads/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/bbox_heads
# copying build/lib/mmdet/models/roi_heads/bbox_heads/double_bbox_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/bbox_heads
# copying build/lib/mmdet/models/roi_heads/bbox_heads/convfc_bbox_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/bbox_heads
# copying build/lib/mmdet/models/roi_heads/bbox_heads/dii_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/bbox_heads
# copying build/lib/mmdet/models/roi_heads/bbox_heads/bbox_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/bbox_heads
# copying build/lib/mmdet/models/roi_heads/bbox_heads/sabl_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/bbox_heads
# copying build/lib/mmdet/models/roi_heads/bbox_heads/scnet_bbox_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads/bbox_heads
# copying build/lib/mmdet/models/roi_heads/grid_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/scnet_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/htc_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/mask_scoring_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/test_mixins.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/dynamic_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/sparse_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/cascade_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/point_rend_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/roi_heads/base_roi_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/roi_heads
# copying build/lib/mmdet/models/builder.py -> build/bdist.linux-x86_64/egg/mmdet/models
# creating build/bdist.linux-x86_64/egg/mmdet/models/seg_heads
# copying build/lib/mmdet/models/seg_heads/base_semantic_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/seg_heads
# copying build/lib/mmdet/models/seg_heads/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/seg_heads
# copying build/lib/mmdet/models/seg_heads/panoptic_fpn_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/seg_heads
# creating build/bdist.linux-x86_64/egg/mmdet/models/seg_heads/panoptic_fusion_heads
# copying build/lib/mmdet/models/seg_heads/panoptic_fusion_heads/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/seg_heads/panoptic_fusion_heads
# copying build/lib/mmdet/models/seg_heads/panoptic_fusion_heads/heuristic_fusion_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/seg_heads/panoptic_fusion_heads
# copying build/lib/mmdet/models/seg_heads/panoptic_fusion_heads/base_panoptic_fusion_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/seg_heads/panoptic_fusion_heads
# copying build/lib/mmdet/models/seg_heads/panoptic_fusion_heads/maskformer_fusion_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/seg_heads/panoptic_fusion_heads
# creating build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/ascend_ssd_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/maskformer_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/nasfcos_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/yolox_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/fsaf_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/fcos_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/solo_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/atss_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/retina_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/dense_test_mixins.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/embedding_rpn_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/ascend_retina_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/retina_sepbn_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/tood_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/cascade_rpn_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/anchor_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/centernet_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/yolact_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/ld_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/anchor_free_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/centripetal_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/lad_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/detr_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/corner_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/autoassign_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/reppoints_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/base_mask_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/vfnet_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/yolo_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/ga_rpn_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/base_dense_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/deformable_detr_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/ascend_anchor_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/ssd_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/mask2former_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/guided_anchor_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/rpn_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/fovea_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/yolof_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/free_anchor_retina_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/ddod_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/solov2_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/paa_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/sabl_retina_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/gfl_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/pisa_retinanet_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/pisa_ssd_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# copying build/lib/mmdet/models/dense_heads/ga_retina_head.py -> build/bdist.linux-x86_64/egg/mmdet/models/dense_heads
# creating build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/split_batch.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/collect_env.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/misc.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/contextmanagers.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/ascend_util.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/compat_config.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/setup_env.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/replace_cfg_vals.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/rfnext.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/util_random.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/logger.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/profiling.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/memory.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/util_distribution.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# copying build/lib/mmdet/utils/util_mixins.py -> build/bdist.linux-x86_64/egg/mmdet/utils
# creating build/bdist.linux-x86_64/egg/mmdet/apis
# copying build/lib/mmdet/apis/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/apis
# copying build/lib/mmdet/apis/train.py -> build/bdist.linux-x86_64/egg/mmdet/apis
# copying build/lib/mmdet/apis/inference.py -> build/bdist.linux-x86_64/egg/mmdet/apis
# copying build/lib/mmdet/apis/test.py -> build/bdist.linux-x86_64/egg/mmdet/apis
# copying build/lib/mmdet/version.py -> build/bdist.linux-x86_64/egg/mmdet
# creating build/bdist.linux-x86_64/egg/mmdet/core
# copying build/lib/mmdet/core/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/core
# creating build/bdist.linux-x86_64/egg/mmdet/core/evaluation
# copying build/lib/mmdet/core/evaluation/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/core/evaluation
# copying build/lib/mmdet/core/evaluation/class_names.py -> build/bdist.linux-x86_64/egg/mmdet/core/evaluation
# copying build/lib/mmdet/core/evaluation/bbox_overlaps.py -> build/bdist.linux-x86_64/egg/mmdet/core/evaluation
# copying build/lib/mmdet/core/evaluation/recall.py -> build/bdist.linux-x86_64/egg/mmdet/core/evaluation
# copying build/lib/mmdet/core/evaluation/eval_hooks.py -> build/bdist.linux-x86_64/egg/mmdet/core/evaluation
# copying build/lib/mmdet/core/evaluation/panoptic_utils.py -> build/bdist.linux-x86_64/egg/mmdet/core/evaluation
# copying build/lib/mmdet/core/evaluation/mean_ap.py -> build/bdist.linux-x86_64/egg/mmdet/core/evaluation
# creating build/bdist.linux-x86_64/egg/mmdet/core/utils
# copying build/lib/mmdet/core/utils/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/core/utils
# copying build/lib/mmdet/core/utils/misc.py -> build/bdist.linux-x86_64/egg/mmdet/core/utils
# copying build/lib/mmdet/core/utils/dist_utils.py -> build/bdist.linux-x86_64/egg/mmdet/core/utils
# creating build/bdist.linux-x86_64/egg/mmdet/core/data_structures
# copying build/lib/mmdet/core/data_structures/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/core/data_structures
# copying build/lib/mmdet/core/data_structures/general_data.py -> build/bdist.linux-x86_64/egg/mmdet/core/data_structures
# copying build/lib/mmdet/core/data_structures/instance_data.py -> build/bdist.linux-x86_64/egg/mmdet/core/data_structures
# creating build/bdist.linux-x86_64/egg/mmdet/core/bbox
# creating build/bdist.linux-x86_64/egg/mmdet/core/bbox/match_costs
# copying build/lib/mmdet/core/bbox/match_costs/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/match_costs
# copying build/lib/mmdet/core/bbox/match_costs/match_cost.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/match_costs
# copying build/lib/mmdet/core/bbox/match_costs/builder.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/match_costs
# copying build/lib/mmdet/core/bbox/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox
# copying build/lib/mmdet/core/bbox/transforms.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox
# creating build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners
# copying build/lib/mmdet/core/bbox/assigners/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners
# copying build/lib/mmdet/core/bbox/assigners/ascend_max_iou_assigner.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners
# copying build/lib/mmdet/core/bbox/assigners/region_assigner.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners
# copying build/lib/mmdet/core/bbox/assigners/mask_hungarian_assigner.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners
# copying build/lib/mmdet/core/bbox/assigners/approx_max_iou_assigner.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners
# copying build/lib/mmdet/core/bbox/assigners/base_assigner.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners
# copying build/lib/mmdet/core/bbox/assigners/sim_ota_assigner.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners
# copying build/lib/mmdet/core/bbox/assigners/atss_assigner.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners
# copying build/lib/mmdet/core/bbox/assigners/point_assigner.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners
# copying build/lib/mmdet/core/bbox/assigners/assign_result.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners
# copying build/lib/mmdet/core/bbox/assigners/uniform_assigner.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners
# copying build/lib/mmdet/core/bbox/assigners/task_aligned_assigner.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners
# copying build/lib/mmdet/core/bbox/assigners/hungarian_assigner.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners
# copying build/lib/mmdet/core/bbox/assigners/center_region_assigner.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners
# copying build/lib/mmdet/core/bbox/assigners/max_iou_assigner.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners
# copying build/lib/mmdet/core/bbox/assigners/grid_assigner.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners
# copying build/lib/mmdet/core/bbox/assigners/ascend_assign_result.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners
# creating build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder
# copying build/lib/mmdet/core/bbox/coder/base_bbox_coder.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder
# copying build/lib/mmdet/core/bbox/coder/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder
# copying build/lib/mmdet/core/bbox/coder/pseudo_bbox_coder.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder
# copying build/lib/mmdet/core/bbox/coder/delta_xywh_bbox_coder.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder
# copying build/lib/mmdet/core/bbox/coder/tblr_bbox_coder.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder
# copying build/lib/mmdet/core/bbox/coder/bucketing_bbox_coder.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder
# copying build/lib/mmdet/core/bbox/coder/distance_point_bbox_coder.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder
# copying build/lib/mmdet/core/bbox/coder/legacy_delta_xywh_bbox_coder.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder
# copying build/lib/mmdet/core/bbox/coder/yolo_bbox_coder.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder
# copying build/lib/mmdet/core/bbox/demodata.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox
# copying build/lib/mmdet/core/bbox/builder.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox
# creating build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers
# copying build/lib/mmdet/core/bbox/samplers/combined_sampler.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers
# copying build/lib/mmdet/core/bbox/samplers/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers
# copying build/lib/mmdet/core/bbox/samplers/random_sampler.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers
# copying build/lib/mmdet/core/bbox/samplers/sampling_result.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers
# copying build/lib/mmdet/core/bbox/samplers/instance_balanced_pos_sampler.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers
# copying build/lib/mmdet/core/bbox/samplers/iou_balanced_neg_sampler.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers
# copying build/lib/mmdet/core/bbox/samplers/ohem_sampler.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers
# copying build/lib/mmdet/core/bbox/samplers/mask_sampling_result.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers
# copying build/lib/mmdet/core/bbox/samplers/score_hlr_sampler.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers
# copying build/lib/mmdet/core/bbox/samplers/pseudo_sampler.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers
# copying build/lib/mmdet/core/bbox/samplers/base_sampler.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers
# copying build/lib/mmdet/core/bbox/samplers/mask_pseudo_sampler.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers
# creating build/bdist.linux-x86_64/egg/mmdet/core/bbox/iou_calculators
# copying build/lib/mmdet/core/bbox/iou_calculators/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/iou_calculators
# copying build/lib/mmdet/core/bbox/iou_calculators/iou2d_calculator.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/iou_calculators
# copying build/lib/mmdet/core/bbox/iou_calculators/builder.py -> build/bdist.linux-x86_64/egg/mmdet/core/bbox/iou_calculators
# creating build/bdist.linux-x86_64/egg/mmdet/core/hook
# copying build/lib/mmdet/core/hook/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/core/hook
# copying build/lib/mmdet/core/hook/sync_random_size_hook.py -> build/bdist.linux-x86_64/egg/mmdet/core/hook
# copying build/lib/mmdet/core/hook/checkloss_hook.py -> build/bdist.linux-x86_64/egg/mmdet/core/hook
# copying build/lib/mmdet/core/hook/sync_norm_hook.py -> build/bdist.linux-x86_64/egg/mmdet/core/hook
# copying build/lib/mmdet/core/hook/set_epoch_info_hook.py -> build/bdist.linux-x86_64/egg/mmdet/core/hook
# copying build/lib/mmdet/core/hook/yolox_mode_switch_hook.py -> build/bdist.linux-x86_64/egg/mmdet/core/hook
# copying build/lib/mmdet/core/hook/yolox_lrupdater_hook.py -> build/bdist.linux-x86_64/egg/mmdet/core/hook
# copying build/lib/mmdet/core/hook/ema.py -> build/bdist.linux-x86_64/egg/mmdet/core/hook
# copying build/lib/mmdet/core/hook/memory_profiler_hook.py -> build/bdist.linux-x86_64/egg/mmdet/core/hook
# copying build/lib/mmdet/core/hook/wandblogger_hook.py -> build/bdist.linux-x86_64/egg/mmdet/core/hook
# creating build/bdist.linux-x86_64/egg/mmdet/core/visualization
# copying build/lib/mmdet/core/visualization/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/core/visualization
# copying build/lib/mmdet/core/visualization/image.py -> build/bdist.linux-x86_64/egg/mmdet/core/visualization
# copying build/lib/mmdet/core/visualization/palette.py -> build/bdist.linux-x86_64/egg/mmdet/core/visualization
# creating build/bdist.linux-x86_64/egg/mmdet/core/anchor
# copying build/lib/mmdet/core/anchor/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/core/anchor
# copying build/lib/mmdet/core/anchor/utils.py -> build/bdist.linux-x86_64/egg/mmdet/core/anchor
# copying build/lib/mmdet/core/anchor/point_generator.py -> build/bdist.linux-x86_64/egg/mmdet/core/anchor
# copying build/lib/mmdet/core/anchor/builder.py -> build/bdist.linux-x86_64/egg/mmdet/core/anchor
# copying build/lib/mmdet/core/anchor/anchor_generator.py -> build/bdist.linux-x86_64/egg/mmdet/core/anchor
# creating build/bdist.linux-x86_64/egg/mmdet/core/mask
# copying build/lib/mmdet/core/mask/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/core/mask
# copying build/lib/mmdet/core/mask/structures.py -> build/bdist.linux-x86_64/egg/mmdet/core/mask
# copying build/lib/mmdet/core/mask/utils.py -> build/bdist.linux-x86_64/egg/mmdet/core/mask
# copying build/lib/mmdet/core/mask/mask_target.py -> build/bdist.linux-x86_64/egg/mmdet/core/mask
# creating build/bdist.linux-x86_64/egg/mmdet/core/export
# copying build/lib/mmdet/core/export/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/core/export
# copying build/lib/mmdet/core/export/model_wrappers.py -> build/bdist.linux-x86_64/egg/mmdet/core/export
# copying build/lib/mmdet/core/export/onnx_helper.py -> build/bdist.linux-x86_64/egg/mmdet/core/export
# copying build/lib/mmdet/core/export/pytorch2onnx.py -> build/bdist.linux-x86_64/egg/mmdet/core/export
# creating build/bdist.linux-x86_64/egg/mmdet/core/post_processing
# copying build/lib/mmdet/core/post_processing/matrix_nms.py -> build/bdist.linux-x86_64/egg/mmdet/core/post_processing
# copying build/lib/mmdet/core/post_processing/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/core/post_processing
# copying build/lib/mmdet/core/post_processing/merge_augs.py -> build/bdist.linux-x86_64/egg/mmdet/core/post_processing
# copying build/lib/mmdet/core/post_processing/bbox_nms.py -> build/bdist.linux-x86_64/egg/mmdet/core/post_processing
# creating build/bdist.linux-x86_64/egg/mmdet/core/optimizers
# copying build/lib/mmdet/core/optimizers/__init__.py -> build/bdist.linux-x86_64/egg/mmdet/core/optimizers
# copying build/lib/mmdet/core/optimizers/layer_decay_optimizer_constructor.py -> build/bdist.linux-x86_64/egg/mmdet/core/optimizers
# copying build/lib/mmdet/core/optimizers/builder.py -> build/bdist.linux-x86_64/egg/mmdet/core/optimizers
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/coco_occluded.py to coco_occluded.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/coco_panoptic.py to coco_panoptic.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/xml_style.py to xml_style.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/voc.py to voc.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines/test_time_aug.py to test_time_aug.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines/transforms.py to transforms.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines/compose.py to compose.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines/loading.py to loading.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines/instaboost.py to instaboost.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines/formating.py to formating.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines/auto_augment.py to auto_augment.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/pipelines/formatting.py to formatting.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/cityscapes.py to cityscapes.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/dataset_wrappers.py to dataset_wrappers.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/openimages.py to openimages.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/api_wrappers/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/api_wrappers/coco_api.py to coco_api.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/api_wrappers/panoptic_evaluation.py to panoptic_evaluation.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/coco.py to coco.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/lvis.py to lvis.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/utils.py to utils.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/custom.py to custom.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/builder.py to builder.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/wider_face.py to wider_face.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/samplers/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/datasets/samplers/class_aware_sampler.py to class_aware_sampler.cpython-39.pyc
# ...
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/utils/util_mixins.py to util_mixins.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/apis/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/apis/train.py to train.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/apis/inference.py to inference.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/apis/test.py to test.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/version.py to version.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/evaluation/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/evaluation/class_names.py to class_names.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/evaluation/bbox_overlaps.py to bbox_overlaps.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/evaluation/recall.py to recall.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/evaluation/eval_hooks.py to eval_hooks.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/evaluation/panoptic_utils.py to panoptic_utils.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/evaluation/mean_ap.py to mean_ap.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/utils/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/utils/misc.py to misc.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/utils/dist_utils.py to dist_utils.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/data_structures/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/data_structures/general_data.py to general_data.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/data_structures/instance_data.py to instance_data.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/match_costs/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/match_costs/match_cost.py to match_cost.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/match_costs/builder.py to builder.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/transforms.py to transforms.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/ascend_max_iou_assigner.py to ascend_max_iou_assigner.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/region_assigner.py to region_assigner.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/mask_hungarian_assigner.py to mask_hungarian_assigner.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/approx_max_iou_assigner.py to approx_max_iou_assigner.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/base_assigner.py to base_assigner.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/sim_ota_assigner.py to sim_ota_assigner.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/atss_assigner.py to atss_assigner.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/point_assigner.py to point_assigner.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/assign_result.py to assign_result.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/uniform_assigner.py to uniform_assigner.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/task_aligned_assigner.py to task_aligned_assigner.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/hungarian_assigner.py to hungarian_assigner.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/center_region_assigner.py to center_region_assigner.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/max_iou_assigner.py to max_iou_assigner.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/grid_assigner.py to grid_assigner.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/assigners/ascend_assign_result.py to ascend_assign_result.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/base_bbox_coder.py to base_bbox_coder.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/pseudo_bbox_coder.py to pseudo_bbox_coder.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/delta_xywh_bbox_coder.py to delta_xywh_bbox_coder.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/tblr_bbox_coder.py to tblr_bbox_coder.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/bucketing_bbox_coder.py to bucketing_bbox_coder.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/distance_point_bbox_coder.py to distance_point_bbox_coder.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/legacy_delta_xywh_bbox_coder.py to legacy_delta_xywh_bbox_coder.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/coder/yolo_bbox_coder.py to yolo_bbox_coder.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/demodata.py to demodata.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/builder.py to builder.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/combined_sampler.py to combined_sampler.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/random_sampler.py to random_sampler.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/sampling_result.py to sampling_result.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/instance_balanced_pos_sampler.py to instance_balanced_pos_sampler.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/iou_balanced_neg_sampler.py to iou_balanced_neg_sampler.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/ohem_sampler.py to ohem_sampler.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/mask_sampling_result.py to mask_sampling_result.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/score_hlr_sampler.py to score_hlr_sampler.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/pseudo_sampler.py to pseudo_sampler.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/base_sampler.py to base_sampler.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/samplers/mask_pseudo_sampler.py to mask_pseudo_sampler.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/iou_calculators/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/iou_calculators/iou2d_calculator.py to iou2d_calculator.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/bbox/iou_calculators/builder.py to builder.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/sync_random_size_hook.py to sync_random_size_hook.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/checkloss_hook.py to checkloss_hook.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/sync_norm_hook.py to sync_norm_hook.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/set_epoch_info_hook.py to set_epoch_info_hook.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/yolox_mode_switch_hook.py to yolox_mode_switch_hook.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/yolox_lrupdater_hook.py to yolox_lrupdater_hook.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/ema.py to ema.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/memory_profiler_hook.py to memory_profiler_hook.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/hook/wandblogger_hook.py to wandblogger_hook.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/visualization/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/visualization/image.py to image.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/visualization/palette.py to palette.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/anchor/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/anchor/utils.py to utils.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/anchor/point_generator.py to point_generator.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/anchor/builder.py to builder.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/anchor/anchor_generator.py to anchor_generator.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/mask/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/mask/structures.py to structures.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/mask/utils.py to utils.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/mask/mask_target.py to mask_target.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/export/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/export/model_wrappers.py to model_wrappers.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/export/onnx_helper.py to onnx_helper.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/export/pytorch2onnx.py to pytorch2onnx.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/post_processing/matrix_nms.py to matrix_nms.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/post_processing/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/post_processing/merge_augs.py to merge_augs.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/post_processing/bbox_nms.py to bbox_nms.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/optimizers/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/optimizers/layer_decay_optimizer_constructor.py to layer_decay_optimizer_constructor.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mmdet/core/optimizers/builder.py to builder.cpython-39.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying mmdet.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mmdet.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mmdet.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mmdet.egg-info/not-zip-safe -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mmdet.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mmdet.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# creating 'dist/mmdet-2.28.2-py3.9.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing mmdet-2.28.2-py3.9.egg
# removing '/home/oks/anaconda3/lib/python3.9/site-packages/mmdet-2.28.2-py3.9.egg' (and everything under it)
# creating /home/oks/anaconda3/lib/python3.9/site-packages/mmdet-2.28.2-py3.9.egg
# Extracting mmdet-2.28.2-py3.9.egg to /home/oks/anaconda3/lib/python3.9/site-packages
# mmdet 2.28.2 is already the active version in easy-install.pth
#
# Installed /home/oks/anaconda3/lib/python3.9/site-packages/mmdet-2.28.2-py3.9.egg
# Processing dependencies for mmdet==2.28.2
# Searching for terminaltables==3.1.10
# Best match: terminaltables 3.1.10
# Processing terminaltables-3.1.10-py3.9.egg
# terminaltables 3.1.10 is already the active version in easy-install.pth
#
# Using /home/oks/anaconda3/lib/python3.9/site-packages/terminaltables-3.1.10-py3.9.egg
# Searching for six==1.16.0
# Best match: six 1.16.0
# Adding six 1.16.0 to easy-install.pth file
#
# Using /home/oks/anaconda3/lib/python3.9/site-packages
# Searching for scipy==1.11.1
# Best match: scipy 1.11.1
# Adding scipy 1.11.1 to easy-install.pth file
#
# Using /home/oks/anaconda3/lib/python3.9/site-packages
# Searching for pycocotools==2.0.7
# Best match: pycocotools 2.0.7
# Processing pycocotools-2.0.7-py3.9-linux-x86_64.egg
# pycocotools 2.0.7 is already the active version in easy-install.pth
#
# Using /home/oks/anaconda3/lib/python3.9/site-packages/pycocotools-2.0.7-py3.9-linux-x86_64.egg
# Searching for numpy==1.25.1
# Best match: numpy 1.25.1
# Adding numpy 1.25.1 to easy-install.pth file
# Installing f2py script to /home/oks/anaconda3/bin
# Installing f2py3 script to /home/oks/anaconda3/bin
# Installing f2py3.9 script to /home/oks/anaconda3/bin
#
# Using /home/oks/anaconda3/lib/python3.9/site-packages
# Searching for matplotlib==3.7.2
# Best match: matplotlib 3.7.2
# Adding matplotlib 3.7.2 to easy-install.pth file
#
# Using /home/oks/anaconda3/lib/python3.9/site-packages
# Searching for importlib-resources==6.0.0
# Best match: importlib-resources 6.0.0
# Adding importlib-resources 6.0.0 to easy-install.pth file
#
# Using /home/oks/anaconda3/lib/python3.9/site-packages
# Searching for python-dateutil==2.8.2
# Best match: python-dateutil 2.8.2
# Adding python-dateutil 2.8.2 to easy-install.pth file
#
# Using /home/oks/anaconda3/lib/python3.9/site-packages
# Searching for pyparsing==3.0.9
# Best match: pyparsing 3.0.9
# Adding pyparsing 3.0.9 to easy-install.pth file
#
# Using /home/oks/anaconda3/lib/python3.9/site-packages
# Searching for Pillow==9.4.0
# Best match: Pillow 9.4.0
# Adding Pillow 9.4.0 to easy-install.pth file
#
# Using /home/oks/anaconda3/lib/python3.9/site-packages
# Searching for packaging==23.0
# Best match: packaging 23.0
# Adding packaging 23.0 to easy-install.pth file
#
# Using /home/oks/anaconda3/lib/python3.9/site-packages
# Searching for kiwisolver==1.4.4
# Best match: kiwisolver 1.4.4
# Adding kiwisolver 1.4.4 to easy-install.pth file
#
# Using /home/oks/anaconda3/lib/python3.9/site-packages
# Searching for fonttools==4.41.1
# Best match: fonttools 4.41.1
# Adding fonttools 4.41.1 to easy-install.pth file
# Installing fonttools script to /home/oks/anaconda3/bin
# Installing pyftmerge script to /home/oks/anaconda3/bin
# Installing pyftsubset script to /home/oks/anaconda3/bin
# Installing ttx script to /home/oks/anaconda3/bin
#
# Using /home/oks/anaconda3/lib/python3.9/site-packages
# Searching for cycler==0.11.0
# Best match: cycler 0.11.0
# Adding cycler 0.11.0 to easy-install.pth file
#
# Using /home/oks/anaconda3/lib/python3.9/site-packages
# Searching for contourpy==1.1.0
# Best match: contourpy 1.1.0
# Adding contourpy 1.1.0 to easy-install.pth file
#
# Using /home/oks/anaconda3/lib/python3.9/site-packages
# Searching for zipp==3.11.0
# Best match: zipp 3.11.0
# Adding zipp 3.11.0 to easy-install.pth file
#
# Using /home/oks/anaconda3/lib/python3.9/site-packages
# Finished processing dependencies for mmdet==2.28.2

# %%
from mmdet.apis import init_detector, inference_detector
import mmcv
# Out:
# /home/oks/anaconda3/envs/egha-mm/lib/python3.8/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(

# %% [markdown]
# ### Conversion of PASCAL VOC dataset to MS-COCO format
# #### Paper Section: 3.4 Dataset Conversion
# Steps and code snippets for converting the dataset from PASCAL VOC format to MS-COCO format using a utility..

# %%
# !pwd
# Out:
# /home/oks/people/egha

# %%
# Cloning the voc2coco utility
# !git clone https://github.com/yukkyo/voc2coco.git # voc -> cooo
# Out:
# fatal: 대상 경로가('voc2coco') 이미 있고 빈 디렉터리가 아닙니다.

# %%
# !pwd
# Out:
# /home/oks/people/egha

# %%
# !cat ./faster_rcnn_data/labels.txt
# Out:
# alcohol
# insulting_gesture
# blood
# cigarette
# gun
# knife

# %%
cd ./voc2coco/
# Out:
# /home/oks/people/egha/voc2coco

# %%
# Converting VOC to COCO format for train, validation, and test sets
# !python voc2coco.py --ann_dir ../faster_rcnn_data/rcnn_normal/Annotations \
--ann_ids ../faster_rcnn_data/rcnn_normal/ImageSets/Main/train.txt \
--labels ../faster_rcnn_data/labels.txt \
--output ../faster_rcnn_data/rcnn_normal/train.json \
--ext xml

# !python voc2coco.py --ann_dir ../faster_rcnn_data/rcnn_normal/Annotations \
--ann_ids ../faster_rcnn_data/rcnn_normal/ImageSets/Main/validation.txt \
--labels ../faster_rcnn_data/labels.txt \
--output ../faster_rcnn_data/rcnn_normal/val.json \
--ext xml

# !python voc2coco.py --ann_dir ../faster_rcnn_data/rcnn_normal/Annotations \
--ann_ids ../faster_rcnn_data/rcnn_normal/ImageSets/Main/test.txt \
--labels ../faster_rcnn_data/labels.txt \
--output ../faster_rcnn_data/rcnn_normal/test.json \
--ext xml
# Out:
# Start converting !
# 100%|████████████████████████████████████| 4646/4646 [00:00<00:00, 15152.23it/s]
# Start converting !
# 100%|██████████████████████████████████████| 552/552 [00:00<00:00, 14630.83it/s]
# Start converting !
# 100%|██████████████████████████████████████| 270/270 [00:00<00:00, 14180.24it/s]

# %%
# !cat ../faster_rcnn_data/rcnn_normal/train.json
# Out:
# {"images": [{"file_name": "img_hod_001565.jpg", "height": 303, "width": 455, "id": "img_hod_001565"}, {"file_name": "img_hod_002040.jpg", "height": 612, "width": 408, "id": "img_hod_002040"}, {"file_name": "img_hod_001836.jpg", "height": 408, "width": 612, "id": "img_hod_001836"}, {"file_name": "img_hod_001920.jpg", "height": 408, "width": 612, "id": "img_hod_001920"}, {"file_name": "img_hod_009630.jpg", "height": 626, "width": 418, "id": "img_hod_009630"}, {"file_name": "img_hod_001456.jpg", "height": 612, "width": 567, "id": "img_hod_001456"}, {"file_name": "img_hod_002027.jpg", "height": 408, "width": 612, "id": "img_hod_002027"}, {"file_name": "img_hod_001986.jpg", "height": 330, "width": 612, "id": "img_hod_001986"}, {"file_name": "img_hod_001512.jpg", "height": 324, "width": 395, "id": "img_hod_001512"}, {"file_name": "img_hod_001480.jpg", "height": 586, "width": 612, "id": "img_hod_001480"}, {"file_name": "img_hod_001560.jpg", "height": 359, "width": 239, "id": "img_hod_001560"}, {"file_name": "img_hod_001577.jpg", "height": 405, "width": 612, "id": "img_hod_001577"}, {"file_name": "img_hod_001790.jpg", "height": 408, "width": 612, "id": "img_hod_001790"}, {"file_name": "img_hod_001489.jpg", "height": 408, "width": 612, "id": "img_hod_001489"}, {"file_name": "img_hod_001707.jpg", "height": 407, "width": 612, "id": "img_hod_001707"}, {"file_name": "img_hod_001744.jpg", "height": 406, "width": 612, "id": "img_hod_001744"}, {"file_name": "img_hod_001455.jpg", "height": 459, "width": 612, "id": "img_hod_001455"}, {"file_name": "img_hod_001592.jpg", "height": 408, "width": 612, "id": "img_hod_001592"}, {"file_name": "img_hod_009727.jpg", "height": 417, "width": 626, "id": "img_hod_009727"}, {"file_name": "img_hod_001675.jpg", "height": 408, "width": 612, "id": "img_hod_001675"}, {"file_name": "img_hod_001969.jpg", "height": 408, "width": 612, "id": "img_hod_001969"}, {"file_name": "img_hod_001568.jpg", "height": 425, "width": 369, "id": "img_hod_001568"}, {"file_name": "img_hod_001450.jpg", "height": 395, "width": 612, "id": "img_hod_001450"}, {"file_name": "img_hod_001605.jpg", "height": 408, "width": 612, "id": "img_hod_001605"}, {"file_name": "img_hod_001752.jpg", "height": 432, "width": 612, "id": "img_hod_001752"}, {"file_name": "img_hod_001496.jpg", "height": 612, "width": 438, "id": "img_hod_001496"}, {"file_name": "img_hod_001937.jpg", "height": 612, "width": 457, "id": "img_hod_001937"}, {"file_name": "img_hod_001686.jpg", "height": 315, "width": 612, "id": "img_hod_001686"}, {"file_name": "img_hod_001764.jpg", "height": 405, "width": 612, "id": "img_hod_001764"}, {"file_name": "img_hod_001821.jpg", "height": 406, "width": 612, "id": "img_hod_001821"}, {"file_name": "img_hod_009650.jpg", "height": 626, "width": 418, "id": "img_hod_009650"}, {"file_name": "img_hod_002058.jpg", "height": 408, "width": 612, "id": "img_hod_002058"}, {"file_name": "img_hod_001485.jpg", "height": 408, "width": 612, "id": "img_hod_001485"}, {"file_name": "img_hod_001447.jpg", "height": 408, "width": 612, "id": "img_hod_001447"}, {"file_name": "img_hod_001660.jpg", "height": 408, "width": 612, "id": "img_hod_001660"}, {"file_name": "img_hod_001889.jpg", "height": 408, "width": 612, "id": "img_hod_001889"}, {"file_name": "img_hod_001574.jpg", "height": 308, "width": 462, "id": "img_hod_001574"}, {"file_name": "img_hod_001918.jpg", "height": 612, "width": 408, "id": "img_hod_001918"}, {"file_name": "img_hod_001451.jpg", "height": 408, "width": 612, "id": "img_hod_001451"}, {"file_name": "img_hod_001523.jpg", "height": 337, "width": 418, "id": "img_hod_001523"}, {"file_name": "img_hod_009659.jpg", "height": 626, "width": 418, "id": "img_hod_009659"}, {"file_name": "img_hod_002026.jpg", "height": 408, "width": 612, "id": "img_hod_002026"}, {"file_name": "img_hod_009639.jpg", "height": 417, "width": 626, "id": "img_hod_009639"}, {"file_name": "img_hod_001820.jpg", "height": 408, "width": 612, "id": "img_hod_001820"}, {"file_name": "img_hod_00175 ...

# %%
# !pwd
# Out:
# /home/oks/people/egha/voc2coco

# %%
cd ..
# Out:
# /home/oks/people/egha

# %% [markdown]
# ### Configuration Setup and Model Training
# #### Paper Section: 4.1 Training Procedure
# Detailed code snippets for configuring the training setup, defining the custom dataset class, and initiating the training process.

# %%
# Configuring the dataset, model, and training parameters
from mmcv import Config
from mmdet.datasets.builder import DATASETS
from mmdet.datasets.coco import CocoDataset
from mmdet.apis import set_random_seed, train_detector
from mmdet.models import build_detector

# Defining the custom dataset class
@DATASETS.register_module(force=True)
class HOD(CocoDataset):
    CLASSES = ('alcohol', 'insulting_gesture', 'blood', 'cigarette', 'gun', 'knife')

# %%
# Load the configuration file
config_file = './mmdetection/configs/faster_rcnn/faster_rcnn_r50_fpn_1x_coco.py'
checkpoint_file = './mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth'

# %%
# !pwd
# Out:
# /home/oks/people/egha

# %%
# !cd ./mmdetection; mkdir checkpoints
# !wget -O ./mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth http://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth
# Out:
# mkdir: `checkpoints' 디렉토리를 만들 수 없습니다: 파일이 있습니다
# --2023-10-12 23:06:50--  http://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth
# Resolving download.openmmlab.com (download.openmmlab.com)... 163.181.22.138, 163.181.22.139, 163.181.22.142, ...
# 접속 download.openmmlab.com (download.openmmlab.com)|163.181.22.138|:80... 접속됨.
# HTTP request sent, awaiting response... 200 OK
# Length: 167287506 (160M) [application/octet-stream]
# Saving to: ‘./mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth’
#
# ./mmdetection/check 100%[===================>] 159.54M  11.5MB/s    in 14s
#
# 2023-10-12 23:07:04 (11.4 MB/s) - ‘./mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth’ saved [167287506/167287506]

# %%
# !ls -lia ./mmdetection/checkpoints
# Out:
# 합계 163380
# 3919874 drwxrwxr-x  2 oks oks      4096 10월 12 17:34 .
# 3608728 drwxrwxr-x 19 oks oks      4096 10월 12 17:34 ..
# 3914259 -rw-rw-r--  1 oks oks 167287506 11월  3  2021 faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth

# %%
cfg = Config.fromfile(config_file)
print(cfg.pretty_text)
# Out:
# model = dict(
#     type='FasterRCNN',
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=True,
#         style='pytorch',
#         init_cfg=dict(type='Pretrained', checkpoint='torchvision://resnet50')),
#     neck=dict(
#         type='FPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[8],
#             ratios=[0.5, 1.0, 2.0],
#             strides=[4, 8, 16, 32, 64]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[0.0, 0.0, 0.0, 0.0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=80,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[0.0, 0.0, 0.0, 0.0],
#                 target_stds=[0.1, 0.1, 0.2, 0.2]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0))),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=False,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100)))
# dataset_type = 'CocoDataset'
# data_root = 'data/coco/'
# img_norm_cfg = dict(
#     mean=[123.675, 116.28, 103.53], std=[58.395, 57.12, 57.375], to_rgb=True)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#     dict(type='RandomFlip', flip_ratio=0.5),
#     dict(
#         type='Normalize',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         to_rgb=True),
#     dict(type='Pad', size_divisor=32),
#     dict(type='DefaultFormatBundle'),
#     dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='MultiScaleFlipAug',
#         img_scale=(1333, 800),
#         flip=False,
#         transforms=[
#             dict(type='Resize', keep_ratio=True),
#             dict(type='RandomFlip'),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='ImageToTensor', keys=['img']),
#             dict(type='Collect', keys=['img'])
#         ])
# ]
# data = dict(
#     samples_per_gpu=2,
#     workers_per_gpu=2,
#     train=dict(
#         type='CocoDataset',
#         ann_file='data/coco/annotations/instances_train2017.json',
#         img_prefix='data/coco/train2017/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#             dict(type='RandomFlip', flip_ratio=0.5),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='DefaultFormatBundle'),
#             dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
#         ]),
#     val=dict(
#         type='CocoDataset',
#         ann_file='data/coco/annotations/instances_val2017.json',
#         img_prefix='data/coco/val2017/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]),
#     test=dict(
#         type='CocoDataset',
#         ann_file='data/coco/annotations/instances_val2017.json',
#         img_prefix='data/coco/val2017/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]))
# evaluation = dict(interval=1, metric='bbox')
# optimizer = dict(type='SGD', lr=0.02, momentum=0.9, weight_decay=0.0001)
# optimizer_config = dict(grad_clip=None)
# lr_config = dict(
#     policy='step',
#     warmup='linear',
#     warmup_iters=500,
#     warmup_ratio=0.001,
#     step=[8, 11])
# runner = dict(type='EpochBasedRunner', max_epochs=12)
# checkpoint_config = dict(interval=1)
# log_config = dict(interval=50, hooks=[dict(type='TextLoggerHook')])
# custom_hooks = [dict(type='NumClassCheckHook')]
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = None
# resume_from = None
# workflow = [('train', 1)]
# opencv_num_threads = 0
# mp_start_method = 'fork'
# auto_scale_lr = dict(enable=False, base_batch_size=16)

# %%
name
# Out:
# '/rcnn_normal/'

# %%
# !pwd
# Out:
# /home/oks/people/egha

# %%
from mmcv.runner import HOOKS, Hook

# Adding the SaveBestCheckpointHook class
# This class is designed to save the best model checkpoint based on a specified metric (e.g., bbox_mAP).
@HOOKS.register_module()
class SaveBestCheckpointHook(Hook):
    def __init__(self, out_dir, metric='bbox_mAP', save_optimizer=True):
        self.out_dir = out_dir  # directory where the best checkpoint will be saved
        self.metric = metric  # metric name to monitor and determine the best model
        self.save_optimizer = save_optimizer  # flag to decide whether to save optimizer state or not
        self.best_score = 0.0  # initialize the best score to 0

    def after_train_epoch(self, runner):
        # This method is called after each training epoch
        # It checks if the current epoch score is better than the best recorded so far and saves the model checkpoint if so
        if not self.every_n_epochs(runner, 1):
            return
        from mmcv.runner import save_checkpoint
        if runner.log_buffer.output.get(self.metric, 0) > self.best_score:
            self.best_score = runner.log_buffer.output[self.metric]
            save_checkpoint(runner.model, self.out_dir, optimizer=self.save_optimizer)

# Updating environment parameters for the dataset
cfg.dataset_type = 'HOD'  # Dataset type is set to 'HOD'
cfg.data_root = './faster_rcnn_data' + name  # Root directory path for data

# Updating type, data_root, ann_file, img_prefix environment parameters for train, val, and test datasets
cfg.data.train.type = 'HOD'
cfg.data.train.data_root = './faster_rcnn_data'+ name
cfg.data.train.ann_file = 'train.json'
cfg.data.train.img_prefix = 'JPEGImages'

cfg.data.val.type = 'HOD'
cfg.data.val.data_root = './faster_rcnn_data' + name
cfg.data.val.ann_file = 'val.json'
cfg.data.val.img_prefix = 'JPEGImages'

cfg.data.test.type = 'HOD'
cfg.data.test.data_root = './faster_rcnn_data' + name
cfg.data.test.ann_file = 'test.json'
cfg.data.test.img_prefix = 'JPEGImages'

# Updating the number of classes
cfg.model.roi_head.bbox_head.num_classes = 6  # Number of classes is set to 6

# Loading the pretrained model
cfg.load_from = './mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth'  # Path to the pretrained model

# Setting the directory to save the training weight files
cfg.work_dir = './tutorial_exps_normal'  # Directory to save training logs and weight files

# Updating the learning rate environment parameter
cfg.optimizer.lr = 0.02 / 8  # Learning rate is set to 0.02 / 8
cfg.lr_config.warmup = None  # Warmup is disabled
cfg.log_config.interval = 2000  # Logging interval is set to 2000

# For CocoDataset, the metric should be set to 'bbox' (not mAP). Setting it to 'bbox' calculates mAP over a range of IoU thresholds (0.5 to 0.95)
cfg.evaluation.metric = 'bbox'
cfg.evaluation.classwise = True  # Additional setting for label-wise mAP

cfg.evaluation.interval = 2000  # Evaluation interval is set to 2000
cfg.checkpoint_config.interval = 5  # Checkpoint saving interval is set to 5

# Adding a setting to save the best performing model
# Adding a custom hook to the cfg setting
cfg.custom_hooks = [dict(type='SaveBestCheckpointHook', out_dir=cfg.work_dir, metric='bbox_mAP', save_optimizer=True)]

# If the config is loaded twice, the lr_config's policy disappears. So, it's set here again.
cfg.lr_config.policy='step'  # Setting the learning rate policy to 'step'

# Setting seed for reproducibility
cfg.seed = 0  # Seed is set to 0
set_random_seed(0, deterministic=False)  # Setting random seed with deterministic set to False
cfg.gpu_ids = range(1)  # Setting GPU IDs

# Changing the evaluation metric since a customized dataset is used
cfg.device = 'cuda'  # Setting device to cuda

cfg.runner.max_epochs = 150  # Setting max epochs to 150for training

# %%
print(cfg.pretty_text)
# Out:
# model = dict(
#     type='FasterRCNN',
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=True,
#         style='pytorch',
#         init_cfg=dict(type='Pretrained', checkpoint='torchvision://resnet50')),
#     neck=dict(
#         type='FPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[8],
#             ratios=[0.5, 1.0, 2.0],
#             strides=[4, 8, 16, 32, 64]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[0.0, 0.0, 0.0, 0.0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=6,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[0.0, 0.0, 0.0, 0.0],
#                 target_stds=[0.1, 0.1, 0.2, 0.2]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0))),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=False,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100)))
# dataset_type = 'HOD'
# data_root = './faster_rcnn_data/rcnn_normal/'
# img_norm_cfg = dict(
#     mean=[123.675, 116.28, 103.53], std=[58.395, 57.12, 57.375], to_rgb=True)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#     dict(type='RandomFlip', flip_ratio=0.5),
#     dict(
#         type='Normalize',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         to_rgb=True),
#     dict(type='Pad', size_divisor=32),
#     dict(type='DefaultFormatBundle'),
#     dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='MultiScaleFlipAug',
#         img_scale=(1333, 800),
#         flip=False,
#         transforms=[
#             dict(type='Resize', keep_ratio=True),
#             dict(type='RandomFlip'),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='ImageToTensor', keys=['img']),
#             dict(type='Collect', keys=['img'])
#         ])
# ]
# data = dict(
#     samples_per_gpu=2,
#     workers_per_gpu=2,
#     train=dict(
#         type='HOD',
#         ann_file='train.json',
#         img_prefix='JPEGImages',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#             dict(type='RandomFlip', flip_ratio=0.5),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='DefaultFormatBundle'),
#             dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
#         ],
#         data_root='./faster_rcnn_data/rcnn_normal/'),
#     val=dict(
#         type='HOD',
#         ann_file='val.json',
#         img_prefix='JPEGImages',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ],
#         data_root='./faster_rcnn_data/rcnn_normal/'),
#     test=dict(
#         type='HOD',
#         ann_file='test.json',
#         img_prefix='JPEGImages',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ],
#         data_root='./faster_rcnn_data/rcnn_normal/'))
# evaluation = dict(interval=2000, metric='bbox', classwise=True)
# optimizer = dict(type='SGD', lr=0.0025, momentum=0.9, weight_decay=0.0001)
# optimizer_config = dict(grad_clip=None)
# lr_config = dict(
#     policy='step',
#     warmup=None,
#     warmup_iters=500,
#     warmup_ratio=0.001,
#     step=[8, 11])
# runner = dict(type='EpochBasedRunner', max_epochs=1)
# checkpoint_config = dict(interval=5)
# log_config = dict(interval=2000, hooks=[dict(type='TextLoggerHook')])
# custom_hooks = [
#     dict(
#         type='SaveBestCheckpointHook',
#         out_dir='./tutorial_exps_normal',
#         metric='bbox_mAP',
#         save_optimizer=True)
# ]
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = './mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth'
# resume_from = None
# workflow = [('train', 1)]
# opencv_num_threads = 0
# mp_start_method = 'fork'
# auto_scale_lr = dict(enable=False, base_batch_size=16)
# work_dir = './tutorial_exps_normal'
# seed = 0
# gpu_ids = range(0, 1)
# device = 'cuda'

# %%
from mmdet.datasets import build_dataset
from mmdet.models import build_detector
from mmdet.apis import train_detector

# Create a dataset for training
datasets = [build_dataset(cfg.data.train)]
# Out:
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!

# %%
# Print the first dataset to check its content
print(datasets[0])

# Using datasets[0].__dict__ to view all the self variables' keys and values.
datasets[0].__dict__.keys()
# Out:
# HOD Train dataset with number of images 4646, and instance counts:
# +-------------+-------+-----------------------+-------+-----------+-------+---------------+-------+----------+-------+
# | category    | count | category              | count | category  | count | category      | count | category | count |
# +-------------+-------+-----------------------+-------+-----------+-------+---------------+-------+----------+-------+
# | 0 [alcohol] | 453   | 1 [insulting_gesture] | 396   | 2 [blood] | 470   | 3 [cigarette] | 467   | 4 [gun]  | 849   |
# |             |       |                       |       |           |       |               |       |          |       |
# | 5 [knife]   | 2011  |                       |       |           |       |               |       |          |       |
# +-------------+-------+-----------------------+-------+-----------+-------+---------------+-------+----------+-------+
# dict_keys(['ann_file', 'data_root', 'img_prefix', 'seg_prefix', 'seg_suffix', 'proposal_file', 'test_mode', 'filter_empty_gt', 'file_client', 'CLASSES', 'coco', 'cat_ids', 'cat2label', 'img_ids', 'data_infos', 'proposals', 'flag', 'pipeline'])

# %%
datasets[0].data_infos
# Out:
# [{'file_name': 'img_hod_001565.jpg',
#   'height': 303,
#   'width': 455,
#   'id': 'img_hod_001565',
#   'filename': 'img_hod_001565.jpg'},
#  {'file_name': 'img_hod_002040.jpg',
#   'height': 612,
#   'width': 408,
#   'id': 'img_hod_002040',
#   'filename': 'img_hod_002040.jpg'},
#  {'file_name': 'img_hod_001836.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001836',
#   'filename': 'img_hod_001836.jpg'},
#  {'file_name': 'img_hod_001920.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001920',
#   'filename': 'img_hod_001920.jpg'},
#  {'file_name': 'img_hod_009630.jpg',
#   'height': 626,
#   'width': 418,
#   'id': 'img_hod_009630',
#   'filename': 'img_hod_009630.jpg'},
#  {'file_name': 'img_hod_001456.jpg',
#   'height': 612,
#   'width': 567,
#   'id': 'img_hod_001456',
#   'filename': 'img_hod_001456.jpg'},
#  {'file_name': 'img_hod_002027.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002027',
#   'filename': 'img_hod_002027.jpg'},
#  {'file_name': 'img_hod_001986.jpg',
#   'height': 330,
#   'width': 612,
#   'id': 'img_hod_001986',
#   'filename': 'img_hod_001986.jpg'},
#  {'file_name': 'img_hod_001512.jpg',
#   'height': 324,
#   'width': 395,
#   'id': 'img_hod_001512',
#   'filename': 'img_hod_001512.jpg'},
#  {'file_name': 'img_hod_001480.jpg',
#   'height': 586,
#   'width': 612,
#   'id': 'img_hod_001480',
#   'filename': 'img_hod_001480.jpg'},
#  {'file_name': 'img_hod_001560.jpg',
#   'height': 359,
#   'width': 239,
#   'id': 'img_hod_001560',
#   'filename': 'img_hod_001560.jpg'},
#  {'file_name': 'img_hod_001577.jpg',
#   'height': 405,
#   'width': 612,
#   'id': 'img_hod_001577',
#   'filename': 'img_hod_001577.jpg'},
#  {'file_name': 'img_hod_001790.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001790',
#   'filename': 'img_hod_001790.jpg'},
#  {'file_name': 'img_hod_001489.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001489',
#   'filename': 'img_hod_001489.jpg'},
#  {'file_name': 'img_hod_001707.jpg',
#   'height': 407,
#   'width': 612,
#   'id': 'img_hod_001707',
#   'filename': 'img_hod_001707.jpg'},
#  {'file_name': 'img_hod_001744.jpg',
#   'height': 406,
#   'width': 612,
#   'id': 'img_hod_001744',
#   'filename': 'img_hod_001744.jpg'},
#  {'file_name': 'img_hod_001455.jpg',
#   'height': 459,
#   'width': 612,
#   'id': 'img_hod_001455',
#   'filename': 'img_hod_001455.jpg'},
#  {'file_name': 'img_hod_001592.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001592',
#   'filename': 'img_hod_001592.jpg'},
#  {'file_name': 'img_hod_009727.jpg',
#   'height': 417,
#   'width': 626,
#   'id': 'img_hod_009727',
#   'filename': 'img_hod_009727.jpg'},
#  {'file_name': 'img_hod_001675.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001675',
#   'filename': 'img_hod_001675.jpg'},
#  {'file_name': 'img_hod_001969.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001969',
#   'filename': 'img_hod_001969.jpg'},
#  {'file_name': 'img_hod_001568.jpg',
#   'height': 425,
#   'width': 369,
#   'id': 'img_hod_001568',
#   'filename': 'img_hod_001568.jpg'},
#  {'file_name': 'img_hod_001450.jpg',
#   'height': 395,
#   'width': 612,
#   'id': 'img_hod_001450',
#   'filename': 'img_hod_001450.jpg'},
#  {'file_name': 'img_hod_001605.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001605',
#   'filename': 'img_hod_001605.jpg'},
#  {'file_name': 'img_hod_001752.jpg',
#   'height': 432,
#   'width': 612,
#   'id': 'img_hod_001752',
#   'filename': 'img_hod_001752.jpg'},
#  {'file_name': 'img_hod_001496.jpg',
#   'height': 612,
#   'width': 438,
#   'id': 'img_hod_001496',
#   'filename': 'img_hod_001496.jpg'},
#  {'file_name': 'img_hod_001937.jpg',
#   'height': 612,
#   'width': 457,
#   'id': 'img_hod_001937',
#   'filename': 'img_hod_001937.jpg'},
#  {'file_name': 'img_hod_001686.jpg',
#   'height': 315,
#   'width': 612,
#   'id': 'img_hod_001686',
#   'filename': 'img_hod_001686.jpg'},
#  {'file_name': 'img_hod_001764.jpg',
#   'height': 405,
#   'width': 612,
#   'id': 'img_hod_001764',
#   'filename': 'img_hod_001764.jpg'},
#  {'file_name': 'img_hod_001821.jpg',
#   'height': 406,
#   'width': 612,
#   'id': 'img_hod_001821',
#   'filename': 'img_hod_001821.jpg'},
#  {'file_name': 'img_hod_009650.jpg',
#   'height': 626,
#   'width': 418,
#   'id': 'img_hod_009650',
#   'filename': 'img_hod_009650.jpg'},
#  {'file_name': 'img_hod_002058.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002058',
#   'filename': 'img_hod_002058.jpg'},
#  {'file_name': 'img_hod_001485.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001485',
#   'filename': 'img_hod_001485.jpg'},
#  {'file_name': 'img_hod_001447.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001447',
#   'filename': 'img_hod_001447.jpg'},
#  {'file_name': 'img_hod_001660.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001660',
#   'filename': 'img_hod_001660.jpg'},
#  {'file_name': 'img_hod_001889.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001889',
#   'filename': 'img_hod_001889.jpg'},
#  {'file_name': 'img_hod_001574.jpg',
#   'height': 308,
#   'width': 462,
#   'id': 'img_hod_001574',
#   'filename': 'img_hod_001574.jpg'},
#  {'file_name': 'img_hod_001918.jpg',
#   'height': 612,
#   'width': 408,
#   'id': 'img_hod_001918',
#   'filename': 'img_hod_001918.jpg'},
#  {'file_name': 'img_hod_001451.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001451',
#   'filename': 'img_hod_001451.jpg'},
#  {'file_name': 'img_hod_001523.jpg',
#   'height': 337,
#   'width': 418,
#   'id': 'img_hod_001523',
#   'filename': 'img_hod_001523.jpg'},
#  {'file_name': 'img_hod_009659.jpg',
#   'height': 626,
#   'width': 418,
#   'id': 'img_hod_009659',
#   'filename': 'img_hod_009659.jpg'},
#  {'file_name': 'img_hod_002026.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002026',
#   'filename': 'img_hod_002026.jpg'},
#  {'file_name': 'img_hod_009639.jpg',
#   'height': 417,
#   'width': 626,
#   'id': 'img_hod_009639',
#   'filename': 'img_hod_009639.jpg'},
#  {'file_name': 'img_hod_001820.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001820',
#   'filename': 'img_hod_001820.jpg'},
#  {'file_name': 'img_hod_001750.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001750',
#   'filename': 'img_hod_001750.jpg'},
#  {'file_name': 'img_hod_001871.jpg',
#   'height': 612,
#   'width': 408,
#   'id': 'img_hod_001871',
#   'filename': 'img_hod_001871.jpg'},
#  {'file_name': 'img_hod_001877.jpg',
#   'height': 391,
#   'width': 612,
#   'id': 'img_hod_001877',
#   'filename': 'img_hod_001877.jpg'},
#  {'file_name': 'img_hod_001754.jpg',
#   'height': 612,
#   'width': 408,
#   'id': 'img_hod_001754',
#   'filename': 'img_hod_001754.jpg'},
#  {'file_name': 'img_hod_001847.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001847',
#   'filename': 'img_hod_001847.jpg'},
#  {'file_name': 'img_hod_001717.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001717',
#   'filename': 'img_hod_001717.jpg'},
#  {'file_name': 'img_hod_001806.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001806',
#   'filename': 'img_hod_001806.jpg'},
#  {'file_name': 'img_hod_001580.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001580',
#   'filename': 'img_hod_001580.jpg'},
#  {'file_name': 'img_hod_009668.jpg',
#   'height': 626,
#   'width': 417,
#   'id': 'img_hod_009668',
#   'filename': 'img_hod_009668.jpg'},
#  {'file_name': 'img_hod_001641.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001641',
#   'filename': 'img_hod_001641.jpg'},
#  {'file_name': 'img_hod_001907.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001907',
#   'filename': 'img_hod_001907.jpg'},
#  {'file_name': 'img_hod_001510.jpg',
#   'height': 344,
#   'width': 418,
#   'id': 'img_hod_001510',
#   'filename': 'img_hod_001510.jpg'},
#  {'file_name': 'img_hod_010206.jpg',
#   'height': 3500,
#   'width': 2333,
#   'id': 'img_hod_010206',
#   'filename': 'img_hod_010206.jpg'},
#  {'file_name': 'img_hod_002011.jpg',
#   'height': 390,
#   'width': 612,
#   'id': 'img_hod_002011',
#   'filename': 'img_hod_002011.jpg'},
#  {'file_name': 'img_hod_001492.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001492',
#   'filename': 'img_hod_001492.jpg'},
#  {'file_name': 'img_hod_001761.jpg',
#   'height': 612,
#   'width': 408,
#   'id': 'img_hod_001761',
#   'filename': 'img_hod_001761.jpg'},
#  {'file_name': 'img_hod_001786.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001786',
#   'filename': 'img_hod_001786.jpg'},
#  {'file_name': 'img_hod_001962.jpg',
#   'height': 538,
#   'width': 612,
#   'id': 'img_hod_001962',
#   'filename': 'img_hod_001962.jpg'},
#  {'file_name': 'img_hod_001566.jpg',
#   'height': 306,
#   'width': 458,
#   'id': 'img_hod_001566',
#   'filename': 'img_hod_001566.jpg'},
#  {'file_name': 'img_hod_001743.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001743',
#   'filename': 'img_hod_001743.jpg'},
#  {'file_name': 'img_hod_009635.jpg',
#   'height': 626,
#   'width': 417,
#   'id': 'img_hod_009635',
#   'filename': 'img_hod_009635.jpg'},
#  {'file_name': 'img_hod_001785.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001785',
#   'filename': 'img_hod_001785.jpg'},
#  {'file_name': 'img_hod_002033.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002033',
#   'filename': 'img_hod_002033.jpg'},
#  {'file_name': 'img_hod_001857.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001857',
#   'filename': 'img_hod_001857.jpg'},
#  {'file_name': 'img_hod_001723.jpg',
#   'height': 388,
#   'width': 612,
#   'id': 'img_hod_001723',
#   'filename': 'img_hod_001723.jpg'},
#  {'file_name': 'img_hod_001690.jpg',
#   'height': 478,
#   'width': 612,
#   'id': 'img_hod_001690',
#   'filename': 'img_hod_001690.jpg'},
#  {'file_name': 'img_hod_001663.jpg',
#   'height': 459,
#   'width': 612,
#   'id': 'img_hod_001663',
#   'filename': 'img_hod_001663.jpg'},
#  {'file_name': 'img_hod_001709.jpg',
#   'height': 612,
#   'width': 420,
#   'id': 'img_hod_001709',
#   'filename': 'img_hod_001709.jpg'},
#  {'file_name': 'img_hod_009712.jpg',
#   'height': 517,
#   'width': 626,
#   'id': 'img_hod_009712',
#   'filename': 'img_hod_009712.jpg'},
#  {'file_name': 'img_hod_001953.jpg',
#   'height': 572,
#   'width': 612,
#   'id': 'img_hod_001953',
#   'filename': 'img_hod_001953.jpg'},
#  {'file_name': 'img_hod_001725.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001725',
#   'filename': 'img_hod_001725.jpg'},
#  {'file_name': 'img_hod_001556.jpg',
#   'height': 322,
#   'width': 484,
#   'id': 'img_hod_001556',
#   'filename': 'img_hod_001556.jpg'},
#  {'file_name': 'img_hod_009669.jpg',
#   'height': 626,
#   'width': 610,
#   'id': 'img_hod_009669',
#   'filename': 'img_hod_009669.jpg'},
#  {'file_name': 'img_hod_009628.jpg',
#   'height': 417,
#   'width': 626,
#   'id': 'img_hod_009628',
#   'filename': 'img_hod_009628.jpg'},
#  {'file_name': 'img_hod_001555.jpg',
#   'height': 435,
#   'width': 290,
#   'id': 'img_hod_001555',
#   'filename': 'img_hod_001555.jpg'},
#  {'file_name': 'img_hod_001807.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001807',
#   'filename': 'img_hod_001807.jpg'},
#  {'file_name': 'img_hod_001789.jpg',
#   'height': 612,
#   'width': 408,
#   'id': 'img_hod_001789',
#   'filename': 'img_hod_001789.jpg'},
#  {'file_name': 'img_hod_001486.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001486',
#   'filename': 'img_hod_001486.jpg'},
#  {'file_name': 'img_hod_001652.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001652',
#   'filename': 'img_hod_001652.jpg'},
#  {'file_name': 'img_hod_009687.jpg',
#   'height': 417,
#   'width': 626,
#   'id': 'img_hod_009687',
#   'filename': 'img_hod_009687.jpg'},
#  {'file_name': 'img_hod_001956.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001956',
#   'filename': 'img_hod_001956.jpg'},
#  {'file_name': 'img_hod_009641.jpg',
#   'height': 417,
#   'width': 626,
#   'id': 'img_hod_009641',
#   'filename': 'img_hod_009641.jpg'},
#  {'file_name': 'img_hod_001925.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001925',
#   'filename': 'img_hod_001925.jpg'},
#  {'file_name': 'img_hod_001946.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001946',
#   'filename': 'img_hod_001946.jpg'},
#  {'file_name': 'img_hod_001579.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001579',
#   'filename': 'img_hod_001579.jpg'},
#  {'file_name': 'img_hod_001830.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001830',
#   'filename': 'img_hod_001830.jpg'},
#  {'file_name': 'img_hod_009648.jpg',
#   'height': 417,
#   'width': 626,
#   'id': 'img_hod_009648',
#   'filename': 'img_hod_009648.jpg'},
#  {'file_name': 'img_hod_001608.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001608',
#   'filename': 'img_hod_001608.jpg'},
#  {'file_name': 'img_hod_001882.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001882',
#   'filename': 'img_hod_001882.jpg'},
#  {'file_name': 'img_hod_001671.jpg',
#   'height': 612,
#   'width': 612,
#   'id': 'img_hod_001671',
#   'filename': 'img_hod_001671.jpg'},
#  {'file_name': 'img_hod_009711.jpg',
#   'height': 626,
#   'width': 417,
#   'id': 'img_hod_009711',
#   'filename': 'img_hod_009711.jpg'},
#  {'file_name': 'img_hod_001666.jpg',
#   'height': 428,
#   'width': 612,
#   'id': 'img_hod_001666',
#   'filename': 'img_hod_001666.jpg'},
#  {'file_name': 'img_hod_001796.jpg',
#   'height': 419,
#   'width': 612,
#   'id': 'img_hod_001796',
#   'filename': 'img_hod_001796.jpg'},
#  {'file_name': 'img_hod_001832.jpg',
#   'height': 343,
#   'width': 612,
#   'id': 'img_hod_001832',
#   'filename': 'img_hod_001832.jpg'},
#  {'file_name': 'img_hod_001599.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001599',
#   'filename': 'img_hod_001599.jpg'},
#  {'file_name': 'img_hod_001637.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001637',
#   'filename': 'img_hod_001637.jpg'},
#  {'file_name': 'img_hod_001867.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001867',
#   'filename': 'img_hod_001867.jpg'},
#  {'file_name': 'img_hod_009729.jpg',
#   'height': 417,
#   'width': 626,
#   'id': 'img_hod_009729',
#   'filename': 'img_hod_009729.jpg'},
#  {'file_name': 'img_hod_001676.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001676',
#   'filename': 'img_hod_001676.jpg'},
#  {'file_name': 'img_hod_001864.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001864',
#   'filename': 'img_hod_001864.jpg'},
#  {'file_name': 'img_hod_002012.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002012',
#   'filename': 'img_hod_002012.jpg'},
#  {'file_name': 'img_hod_001505.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001505',
#   'filename': 'img_hod_001505.jpg'},
#  {'file_name': 'img_hod_001598.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001598',
#   'filename': 'img_hod_001598.jpg'},
#  {'file_name': 'img_hod_002005.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002005',
#   'filename': 'img_hod_002005.jpg'},
#  {'file_name': 'img_hod_001503.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001503',
#   'filename': 'img_hod_001503.jpg'},
#  {'file_name': 'img_hod_001561.jpg',
#   'height': 431,
#   'width': 286,
#   'id': 'img_hod_001561',
#   'filename': 'img_hod_001561.jpg'},
#  {'file_name': 'img_hod_001545.jpg',
#   'height': 262,
#   'width': 362,
#   'id': 'img_hod_001545',
#   'filename': 'img_hod_001545.jpg'},
#  {'file_name': 'img_hod_001784.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001784',
#   'filename': 'img_hod_001784.jpg'},
#  {'file_name': 'img_hod_001538.jpg',
#   'height': 296,
#   'width': 410,
#   'id': 'img_hod_001538',
#   'filename': 'img_hod_001538.jpg'},
#  {'file_name': 'img_hod_001976.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001976',
#   'filename': 'img_hod_001976.jpg'},
#  {'file_name': 'img_hod_001689.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001689',
#   'filename': 'img_hod_001689.jpg'},
#  {'file_name': 'img_hod_001479.jpg',
#   'height': 510,
#   'width': 612,
#   'id': 'img_hod_001479',
#   'filename': 'img_hod_001479.jpg'},
#  {'file_name': 'img_hod_001536.jpg',
#   'height': 372,
#   'width': 493,
#   'id': 'img_hod_001536',
#   'filename': 'img_hod_001536.jpg'},
#  {'file_name': 'img_hod_009638.jpg',
#   'height': 506,
#   'width': 626,
#   'id': 'img_hod_009638',
#   'filename': 'img_hod_009638.jpg'},
#  {'file_name': 'img_hod_002032.jpg',
#   'height': 612,
#   'width': 408,
#   'id': 'img_hod_002032',
#   'filename': 'img_hod_002032.jpg'},
#  {'file_name': 'img_hod_001977.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001977',
#   'filename': 'img_hod_001977.jpg'},
#  {'file_name': 'img_hod_001593.jpg',
#   'height': 344,
#   'width': 612,
#   'id': 'img_hod_001593',
#   'filename': 'img_hod_001593.jpg'},
#  {'file_name': 'img_hod_001595.jpg',
#   'height': 612,
#   'width': 409,
#   'id': 'img_hod_001595',
#   'filename': 'img_hod_001595.jpg'},
#  {'file_name': 'img_hod_001630.jpg',
#   'height': 344,
#   'width': 612,
#   'id': 'img_hod_001630',
#   'filename': 'img_hod_001630.jpg'},
#  {'file_name': 'img_hod_001818.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001818',
#   'filename': 'img_hod_001818.jpg'},
#  {'file_name': 'img_hod_001506.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001506',
#   'filename': 'img_hod_001506.jpg'},
#  {'file_name': 'img_hod_001747.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001747',
#   'filename': 'img_hod_001747.jpg'},
#  {'file_name': 'img_hod_002001.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002001',
#   'filename': 'img_hod_002001.jpg'},
#  {'file_name': 'img_hod_001914.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001914',
#   'filename': 'img_hod_001914.jpg'},
#  {'file_name': 'img_hod_001672.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001672',
#   'filename': 'img_hod_001672.jpg'},
#  {'file_name': 'img_hod_002020.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002020',
#   'filename': 'img_hod_002020.jpg'},
#  {'file_name': 'img_hod_001685.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001685',
#   'filename': 'img_hod_001685.jpg'},
#  {'file_name': 'img_hod_001859.jpg',
#   'height': 406,
#   'width': 612,
#   'id': 'img_hod_001859',
#   'filename': 'img_hod_001859.jpg'},
#  {'file_name': 'img_hod_001834.jpg',
#   'height': 405,
#   'width': 612,
#   'id': 'img_hod_001834',
#   'filename': 'img_hod_001834.jpg'},
#  {'file_name': 'img_hod_010204.jpg',
#   'height': 5472,
#   'width': 3648,
#   'id': 'img_hod_010204',
#   'filename': 'img_hod_010204.jpg'},
#  {'file_name': 'img_hod_001661.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001661',
#   'filename': 'img_hod_001661.jpg'},
#  {'file_name': 'img_hod_002015.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002015',
#   'filename': 'img_hod_002015.jpg'},
#  {'file_name': 'img_hod_009680.jpg',
#   'height': 413,
#   'width': 626,
#   'id': 'img_hod_009680',
#   'filename': 'img_hod_009680.jpg'},
#  {'file_name': 'img_hod_001727.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001727',
#   'filename': 'img_hod_001727.jpg'},
#  {'file_name': 'img_hod_001997.jpg',
#   'height': 612,
#   'width': 442,
#   'id': 'img_hod_001997',
#   'filename': 'img_hod_001997.jpg'},
#  {'file_name': 'img_hod_001658.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001658',
#   'filename': 'img_hod_001658.jpg'},
#  {'file_name': 'img_hod_001748.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001748',
#   'filename': 'img_hod_001748.jpg'},
#  {'file_name': 'img_hod_001457.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001457',
#   'filename': 'img_hod_001457.jpg'},
#  {'file_name': 'img_hod_001557.jpg',
#   'height': 303,
#   'width': 455,
#   'id': 'img_hod_001557',
#   'filename': 'img_hod_001557.jpg'},
#  {'file_name': 'img_hod_001713.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001713',
#   'filename': 'img_hod_001713.jpg'},
#  {'file_name': 'img_hod_009673.jpg',
#   'height': 417,
#   'width': 626,
#   'id': 'img_hod_009673',
#   'filename': 'img_hod_009673.jpg'},
#  {'file_name': 'img_hod_001582.jpg',
#   'height': 364,
#   'width': 612,
#   'id': 'img_hod_001582',
#   'filename': 'img_hod_001582.jpg'},
#  {'file_name': 'img_hod_009671.jpg',
#   'height': 626,
#   'width': 507,
#   'id': 'img_hod_009671',
#   'filename': 'img_hod_009671.jpg'},
#  {'file_name': 'img_hod_001979.jpg',
#   'height': 403,
#   'width': 612,
#   'id': 'img_hod_001979',
#   'filename': 'img_hod_001979.jpg'},
#  {'file_name': 'img_hod_001948.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001948',
#   'filename': 'img_hod_001948.jpg'},
#  {'file_name': 'img_hod_001823.jpg',
#   'height': 612,
#   'width': 408,
#   'id': 'img_hod_001823',
#   'filename': 'img_hod_001823.jpg'},
#  {'file_name': 'img_hod_001615.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001615',
#   'filename': 'img_hod_001615.jpg'},
#  {'file_name': 'img_hod_001645.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001645',
#   'filename': 'img_hod_001645.jpg'},
#  {'file_name': 'img_hod_001987.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001987',
#   'filename': 'img_hod_001987.jpg'},
#  {'file_name': 'img_hod_001541.jpg',
#   'height': 421,
#   'width': 504,
#   'id': 'img_hod_001541',
#   'filename': 'img_hod_001541.jpg'},
#  {'file_name': 'img_hod_001935.jpg',
#   'height': 612,
#   'width': 408,
#   'id': 'img_hod_001935',
#   'filename': 'img_hod_001935.jpg'},
#  {'file_name': 'img_hod_001607.jpg',
#   'height': 395,
#   'width': 612,
#   'id': 'img_hod_001607',
#   'filename': 'img_hod_001607.jpg'},
#  {'file_name': 'img_hod_001639.jpg',
#   'height': 612,
#   'width': 408,
#   'id': 'img_hod_001639',
#   'filename': 'img_hod_001639.jpg'},
#  {'file_name': 'img_hod_001493.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001493',
#   'filename': 'img_hod_001493.jpg'},
#  {'file_name': 'img_hod_009733.jpg',
#   'height': 521,
#   'width': 626,
#   'id': 'img_hod_009733',
#   'filename': 'img_hod_009733.jpg'},
#  {'file_name': 'img_hod_001931.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001931',
#   'filename': 'img_hod_001931.jpg'},
#  {'file_name': 'img_hod_001996.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001996',
#   'filename': 'img_hod_001996.jpg'},
#  {'file_name': 'img_hod_001940.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001940',
#   'filename': 'img_hod_001940.jpg'},
#  {'file_name': 'img_hod_009631.jpg',
#   'height': 626,
#   'width': 418,
#   'id': 'img_hod_009631',
#   'filename': 'img_hod_009631.jpg'},
#  {'file_name': 'img_hod_001473.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001473',
#   'filename': 'img_hod_001473.jpg'},
#  {'file_name': 'img_hod_001846.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001846',
#   'filename': 'img_hod_001846.jpg'},
#  {'file_name': 'img_hod_001941.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001941',
#   'filename': 'img_hod_001941.jpg'},
#  {'file_name': 'img_hod_002050.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002050',
#   'filename': 'img_hod_002050.jpg'},
#  {'file_name': 'img_hod_010208.jpg',
#   'height': 6000,
#   'width': 4000,
#   'id': 'img_hod_010208',
#   'filename': 'img_hod_010208.jpg'},
#  {'file_name': 'img_hod_001774.jpg',
#   'height': 418,
#   'width': 612,
#   'id': 'img_hod_001774',
#   'filename': 'img_hod_001774.jpg'},
#  {'file_name': 'img_hod_009697.jpg',
#   'height': 449,
#   'width': 626,
#   'id': 'img_hod_009697',
#   'filename': 'img_hod_009697.jpg'},
#  {'file_name': 'img_hod_001983.jpg',
#   'height': 612,
#   'width': 408,
#   'id': 'img_hod_001983',
#   'filename': 'img_hod_001983.jpg'},
#  {'file_name': 'img_hod_001897.jpg',
#   'height': 612,
#   'width': 408,
#   'id': 'img_hod_001897',
#   'filename': 'img_hod_001897.jpg'},
#  {'file_name': 'img_hod_002023.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002023',
#   'filename': 'img_hod_002023.jpg'},
#  {'file_name': 'img_hod_001917.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001917',
#   'filename': 'img_hod_001917.jpg'},
#  {'file_name': 'img_hod_002037.jpg',
#   'height': 612,
#   'width': 407,
#   'id': 'img_hod_002037',
#   'filename': 'img_hod_002037.jpg'},
#  {'file_name': 'img_hod_001650.jpg',
#   'height': 459,
#   'width': 612,
#   'id': 'img_hod_001650',
#   'filename': 'img_hod_001650.jpg'},
#  {'file_name': 'img_hod_001794.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001794',
#   'filename': 'img_hod_001794.jpg'},
#  {'file_name': 'img_hod_001728.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001728',
#   'filename': 'img_hod_001728.jpg'},
#  {'file_name': 'img_hod_001475.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001475',
#   'filename': 'img_hod_001475.jpg'},
#  {'file_name': 'img_hod_001606.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001606',
#   'filename': 'img_hod_001606.jpg'},
#  {'file_name': 'img_hod_001844.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001844',
#   'filename': 'img_hod_001844.jpg'},
#  {'file_name': 'img_hod_001934.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001934',
#   'filename': 'img_hod_001934.jpg'},
#  {'file_name': 'img_hod_001855.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001855',
#   'filename': 'img_hod_001855.jpg'},
#  {'file_name': 'img_hod_009647.jpg',
#   'height': 417,
#   'width': 626,
#   'id': 'img_hod_009647',
#   'filename': 'img_hod_009647.jpg'},
#  {'file_name': 'img_hod_001613.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001613',
#   'filename': 'img_hod_001613.jpg'},
#  {'file_name': 'img_hod_001854.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001854',
#   'filename': 'img_hod_001854.jpg'},
#  {'file_name': 'img_hod_001596.jpg',
#   'height': 459,
#   'width': 612,
#   'id': 'img_hod_001596',
#   'filename': 'img_hod_001596.jpg'},
#  {'file_name': 'img_hod_002004.jpg',
#   'height': 392,
#   'width': 612,
#   'id': 'img_hod_002004',
#   'filename': 'img_hod_002004.jpg'},
#  {'file_name': 'img_hod_001534.jpg',
#   'height': 330,
#   'width': 468,
#   'id': 'img_hod_001534',
#   'filename': 'img_hod_001534.jpg'},
#  {'file_name': 'img_hod_001576.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001576',
#   'filename': 'img_hod_001576.jpg'},
#  {'file_name': 'img_hod_009700.jpg',
#   'height': 418,
#   'width': 626,
#   'id': 'img_hod_009700',
#   'filename': 'img_hod_009700.jpg'},
#  {'file_name': 'img_hod_002038.jpg',
#   'height': 344,
#   'width': 612,
#   'id': 'img_hod_002038',
#   'filename': 'img_hod_002038.jpg'},
#  {'file_name': 'img_hod_001694.jpg',
#   'height': 430,
#   'width': 612,
#   'id': 'img_hod_001694',
#   'filename': 'img_hod_001694.jpg'},
#  {'file_name': 'img_hod_001504.jpg',
#   'height': 379,
#   'width': 612,
#   'id': 'img_hod_001504',
#   'filename': 'img_hod_001504.jpg'},
#  {'file_name': 'img_hod_009692.jpg',
#   'height': 417,
#   'width': 626,
#   'id': 'img_hod_009692',
#   'filename': 'img_hod_009692.jpg'},
#  {'file_name': 'img_hod_001740.jpg',
#   'height': 490,
#   'width': 612,
#   'id': 'img_hod_001740',
#   'filename': 'img_hod_001740.jpg'},
#  {'file_name': 'img_hod_009646.jpg',
#   'height': 626,
#   'width': 417,
#   'id': 'img_hod_009646',
#   'filename': 'img_hod_009646.jpg'},
#  {'file_name': 'img_hod_009649.jpg',
#   'height': 417,
#   'width': 626,
#   'id': 'img_hod_009649',
#   'filename': 'img_hod_009649.jpg'},
#  {'file_name': 'img_hod_001525.jpg',
#   'height': 335,
#   'width': 438,
#   'id': 'img_hod_001525',
#   'filename': 'img_hod_001525.jpg'},
#  {'file_name': 'img_hod_001758.jpg',
#   'height': 612,
#   'width': 531,
#   'id': 'img_hod_001758',
#   'filename': 'img_hod_001758.jpg'},
#  {'file_name': 'img_hod_001655.jpg',
#   'height': 485,
#   'width': 612,
#   'id': 'img_hod_001655',
#   'filename': 'img_hod_001655.jpg'},
#  {'file_name': 'img_hod_001465.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001465',
#   'filename': 'img_hod_001465.jpg'},
#  {'file_name': 'img_hod_001768.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001768',
#   'filename': 'img_hod_001768.jpg'},
#  {'file_name': 'img_hod_001861.jpg',
#   'height': 499,
#   'width': 612,
#   'id': 'img_hod_001861',
#   'filename': 'img_hod_001861.jpg'},
#  {'file_name': 'img_hod_009690.jpg',
#   'height': 626,
#   'width': 418,
#   'id': 'img_hod_009690',
#   'filename': 'img_hod_009690.jpg'},
#  {'file_name': 'img_hod_001798.jpg',
#   'height': 377,
#   'width': 612,
#   'id': 'img_hod_001798',
#   'filename': 'img_hod_001798.jpg'},
#  {'file_name': 'img_hod_001521.jpg',
#   'height': 371,
#   'width': 359,
#   'id': 'img_hod_001521',
#   'filename': 'img_hod_001521.jpg'},
#  {'file_name': 'img_hod_001670.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001670',
#   'filename': 'img_hod_001670.jpg'},
#  {'file_name': 'img_hod_001448.jpg',
#   'height': 442,
#   'width': 612,
#   'id': 'img_hod_001448',
#   'filename': 'img_hod_001448.jpg'},
#  {'file_name': 'img_hod_001835.jpg',
#   'height': 406,
#   'width': 612,
#   'id': 'img_hod_001835',
#   'filename': 'img_hod_001835.jpg'},
#  {'file_name': 'img_hod_001462.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001462',
#   'filename': 'img_hod_001462.jpg'},
#  {'file_name': 'img_hod_001738.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001738',
#   'filename': 'img_hod_001738.jpg'},
#  {'file_name': 'img_hod_001649.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001649',
#   'filename': 'img_hod_001649.jpg'},
#  {'file_name': 'img_hod_001569.jpg',
#   'height': 375,
#   'width': 300,
#   'id': 'img_hod_001569',
#   'filename': 'img_hod_001569.jpg'},
#  {'file_name': 'img_hod_001522.jpg',
#   'height': 458,
#   'width': 361,
#   'id': 'img_hod_001522',
#   'filename': 'img_hod_001522.jpg'},
#  {'file_name': 'img_hod_002048.jpg',
#   'height': 317,
#   'width': 612,
#   'id': 'img_hod_002048',
#   'filename': 'img_hod_002048.jpg'},
#  {'file_name': 'img_hod_001653.jpg',
#   'height': 391,
#   'width': 612,
#   'id': 'img_hod_001653',
#   'filename': 'img_hod_001653.jpg'},
#  {'file_name': 'img_hod_002039.jpg',
#   'height': 612,
#   'width': 408,
#   'id': 'img_hod_002039',
#   'filename': 'img_hod_002039.jpg'},
#  {'file_name': 'img_hod_002007.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002007',
#   'filename': 'img_hod_002007.jpg'},
#  {'file_name': 'img_hod_001879.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001879',
#   'filename': 'img_hod_001879.jpg'},
#  {'file_name': 'img_hod_001547.jpg',
#   'height': 273,
#   'width': 285,
#   'id': 'img_hod_001547',
#   'filename': 'img_hod_001547.jpg'},
#  {'file_name': 'img_hod_001452.jpg',
#   'height': 372,
#   'width': 612,
#   'id': 'img_hod_001452',
#   'filename': 'img_hod_001452.jpg'},
#  {'file_name': 'img_hod_009666.jpg',
#   'height': 501,
#   'width': 626,
#   'id': 'img_hod_009666',
#   'filename': 'img_hod_009666.jpg'},
#  {'file_name': 'img_hod_001629.jpg',
#   'height': 605,
#   'width': 612,
#   'id': 'img_hod_001629',
#   'filename': 'img_hod_001629.jpg'},
#  {'file_name': 'img_hod_001910.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001910',
#   'filename': 'img_hod_001910.jpg'},
#  {'file_name': 'img_hod_001559.jpg',
#   'height': 445,
#   'width': 297,
#   'id': 'img_hod_001559',
#   'filename': 'img_hod_001559.jpg'},
#  {'file_name': 'img_hod_001921.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001921',
#   'filename': 'img_hod_001921.jpg'},
#  {'file_name': 'img_hod_009674.jpg',
#   'height': 417,
#   'width': 626,
#   'id': 'img_hod_009674',
#   'filename': 'img_hod_009674.jpg'},
#  {'file_name': 'img_hod_001913.jpg',
#   'height': 344,
#   'width': 612,
#   'id': 'img_hod_001913',
#   'filename': 'img_hod_001913.jpg'},
#  {'file_name': 'img_hod_002057.jpg',
#   'height': 406,
#   'width': 612,
#   'id': 'img_hod_002057',
#   'filename': 'img_hod_002057.jpg'},
#  {'file_name': 'img_hod_001881.jpg',
#   'height': 612,
#   'width': 408,
#   'id': 'img_hod_001881',
#   'filename': 'img_hod_001881.jpg'},
#  {'file_name': 'img_hod_009632.jpg',
#   'height': 626,
#   'width': 418,
#   'id': 'img_hod_009632',
#   'filename': 'img_hod_009632.jpg'},
#  {'file_name': 'img_hod_001862.jpg',
#   'height': 612,
#   'width': 408,
#   'id': 'img_hod_001862',
#   'filename': 'img_hod_001862.jpg'},
#  {'file_name': 'img_hod_001688.jpg',
#   'height': 421,
#   'width': 612,
#   'id': 'img_hod_001688',
#   'filename': 'img_hod_001688.jpg'},
#  {'file_name': 'img_hod_001840.jpg',
#   'height': 612,
#   'width': 408,
#   'id': 'img_hod_001840',
#   'filename': 'img_hod_001840.jpg'},
#  {'file_name': 'img_hod_009651.jpg',
#   'height': 626,
#   'width': 418,
#   'id': 'img_hod_009651',
#   'filename': 'img_hod_009651.jpg'},
#  {'file_name': 'img_hod_001526.jpg',
#   'height': 469,
#   'width': 325,
#   'id': 'img_hod_001526',
#   'filename': 'img_hod_001526.jpg'},
#  {'file_name': 'img_hod_001808.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001808',
#   'filename': 'img_hod_001808.jpg'},
#  {'file_name': 'img_hod_002045.jpg',
#   'height': 392,
#   'width': 612,
#   'id': 'img_hod_002045',
#   'filename': 'img_hod_002045.jpg'},
#  {'file_name': 'img_hod_001779.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001779',
#   'filename': 'img_hod_001779.jpg'},
#  {'file_name': 'img_hod_001476.jpg',
#   'height': 344,
#   'width': 612,
#   'id': 'img_hod_001476',
#   'filename': 'img_hod_001476.jpg'},
#  {'file_name': 'img_hod_009642.jpg',
#   'height': 417,
#   'width': 626,
#   'id': 'img_hod_009642',
#   'filename': 'img_hod_009642.jpg'},
#  {'file_name': 'img_hod_001788.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001788',
#   'filename': 'img_hod_001788.jpg'},
#  {'file_name': 'img_hod_001800.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001800',
#   'filename': 'img_hod_001800.jpg'},
#  {'file_name': 'img_hod_001825.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001825',
#   'filename': 'img_hod_001825.jpg'},
#  {'file_name': 'img_hod_002051.jpg',
#   'height': 317,
#   'width': 612,
#   'id': 'img_hod_002051',
#   'filename': 'img_hod_002051.jpg'},
#  {'file_name': 'img_hod_001998.jpg',
#   'height': 612,
#   'width': 408,
#   'id': 'img_hod_001998',
#   'filename': 'img_hod_001998.jpg'},
#  {'file_name': 'img_hod_001483.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001483',
#   'filename': 'img_hod_001483.jpg'},
#  {'file_name': 'img_hod_001954.jpg',
#   'height': 612,
#   'width': 461,
#   'id': 'img_hod_001954',
#   'filename': 'img_hod_001954.jpg'},
#  {'file_name': 'img_hod_001801.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001801',
#   'filename': 'img_hod_001801.jpg'},
#  {'file_name': 'img_hod_001724.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001724',
#   'filename': 'img_hod_001724.jpg'},
#  {'file_name': 'img_hod_001589.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001589',
#   'filename': 'img_hod_001589.jpg'},
#  {'file_name': 'img_hod_009664.jpg',
#   'height': 417,
#   'width': 626,
#   'id': 'img_hod_009664',
#   'filename': 'img_hod_009664.jpg'},
#  {'file_name': 'img_hod_001966.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001966',
#   'filename': 'img_hod_001966.jpg'},
#  {'file_name': 'img_hod_009695.jpg',
#   'height': 417,
#   'width': 626,
#   'id': 'img_hod_009695',
#   'filename': 'img_hod_009695.jpg'},
#  {'file_name': 'img_hod_001657.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001657',
#   'filename': 'img_hod_001657.jpg'},
#  {'file_name': 'img_hod_001553.jpg',
#   'height': 303,
#   'width': 455,
#   'id': 'img_hod_001553',
#   'filename': 'img_hod_001553.jpg'},
#  {'file_name': 'img_hod_001833.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001833',
#   'filename': 'img_hod_001833.jpg'},
#  {'file_name': 'img_hod_001905.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001905',
#   'filename': 'img_hod_001905.jpg'},
#  {'file_name': 'img_hod_001554.jpg',
#   'height': 407,
#   'width': 271,
#   'id': 'img_hod_001554',
#   'filename': 'img_hod_001554.jpg'},
#  {'file_name': 'img_hod_001687.jpg',
#   'height': 406,
#   'width': 612,
#   'id': 'img_hod_001687',
#   'filename': 'img_hod_001687.jpg'},
#  {'file_name': 'img_hod_001567.jpg',
#   'height': 363,
#   'width': 271,
#   'id': 'img_hod_001567',
#   'filename': 'img_hod_001567.jpg'},
#  {'file_name': 'img_hod_001866.jpg',
#   'height': 402,
#   'width': 612,
#   'id': 'img_hod_001866',
#   'filename': 'img_hod_001866.jpg'},
#  {'file_name': 'img_hod_002042.jpg',
#   'height': 612,
#   'width': 408,
#   'id': 'img_hod_002042',
#   'filename': 'img_hod_002042.jpg'},
#  {'file_name': 'img_hod_001603.jpg',
#   'height': 612,
#   'width': 436,
#   'id': 'img_hod_001603',
#   'filename': 'img_hod_001603.jpg'},
#  {'file_name': 'img_hod_009734.jpg',
#   'height': 626,
#   'width': 417,
#   'id': 'img_hod_009734',
#   'filename': 'img_hod_009734.jpg'},
#  {'file_name': 'img_hod_001640.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001640',
#   'filename': 'img_hod_001640.jpg'},
#  {'file_name': 'img_hod_001481.jpg',
#   'height': 612,
#   'width': 459,
#   'id': 'img_hod_001481',
#   'filename': 'img_hod_001481.jpg'},
#  {'file_name': 'img_hod_001721.jpg',
#   'height': 612,
#   'width': 408,
#   'id': 'img_hod_001721',
#   'filename': 'img_hod_001721.jpg'},
#  {'file_name': 'img_hod_001928.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001928',
#   'filename': 'img_hod_001928.jpg'},
#  {'file_name': 'img_hod_001841.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001841',
#   'filename': 'img_hod_001841.jpg'},
#  {'file_name': 'img_hod_001495.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001495',
#   'filename': 'img_hod_001495.jpg'},
#  {'file_name': 'img_hod_001856.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001856',
#   'filename': 'img_hod_001856.jpg'},
#  {'file_name': 'img_hod_002013.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002013',
#   'filename': 'img_hod_002013.jpg'},
#  {'file_name': 'img_hod_001793.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001793',
#   'filename': 'img_hod_001793.jpg'},
#  {'file_name': 'img_hod_001656.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001656',
#   'filename': 'img_hod_001656.jpg'},
#  {'file_name': 'img_hod_001952.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001952',
#   'filename': 'img_hod_001952.jpg'},
#  {'file_name': 'img_hod_001550.jpg',
#   'height': 253,
#   'width': 451,
#   'id': 'img_hod_001550',
#   'filename': 'img_hod_001550.jpg'},
#  {'file_name': 'img_hod_001810.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001810',
#   'filename': 'img_hod_001810.jpg'},
#  {'file_name': 'img_hod_001980.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001980',
#   'filename': 'img_hod_001980.jpg'},
#  {'file_name': 'img_hod_001581.jpg',
#   'height': 612,
#   'width': 417,
#   'id': 'img_hod_001581',
#   'filename': 'img_hod_001581.jpg'},
#  {'file_name': 'img_hod_001762.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001762',
#   'filename': 'img_hod_001762.jpg'},
#  {'file_name': 'img_hod_002030.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002030',
#   'filename': 'img_hod_002030.jpg'},
#  {'file_name': 'img_hod_001654.jpg',
#   'height': 612,
#   'width': 408,
#   'id': 'img_hod_001654',
#   'filename': 'img_hod_001654.jpg'},
#  {'file_name': 'img_hod_002031.jpg',
#   'height': 612,
#   'width': 353,
#   'id': 'img_hod_002031',
#   'filename': 'img_hod_002031.jpg'},
#  {'file_name': 'img_hod_001468.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001468',
#   'filename': 'img_hod_001468.jpg'},
#  {'file_name': 'img_hod_009718.jpg',
#   'height': 626,
#   'width': 474,
#   'id': 'img_hod_009718',
#   'filename': 'img_hod_009718.jpg'},
#  {'file_name': 'img_hod_001967.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001967',
#   'filename': 'img_hod_001967.jpg'},
#  {'file_name': 'img_hod_001509.jpg',
#   'height': 442,
#   'width': 358,
#   'id': 'img_hod_001509',
#   'filename': 'img_hod_001509.jpg'},
#  {'file_name': 'img_hod_001648.jpg',
#   'height': 414,
#   'width': 612,
#   'id': 'img_hod_001648',
#   'filename': 'img_hod_001648.jpg'},
#  {'file_name': 'img_hod_001938.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001938',
#   'filename': 'img_hod_001938.jpg'},
#  {'file_name': 'img_hod_001712.jpg',
#   'height': 612,
#   'width': 408,
#   'id': 'img_hod_001712',
#   'filename': 'img_hod_001712.jpg'},
#  {'file_name': 'img_hod_001677.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001677',
#   'filename': 'img_hod_001677.jpg'},
#  {'file_name': 'img_hod_001819.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001819',
#   'filename': 'img_hod_001819.jpg'},
#  {'file_name': 'img_hod_002059.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002059',
#   'filename': 'img_hod_002059.jpg'},
#  {'file_name': 'img_hod_001539.jpg',
#   'height': 407,
#   'width': 381,
#   'id': 'img_hod_001539',
#   'filename': 'img_hod_001539.jpg'},
#  {'file_name': 'img_hod_001703.jpg',
#   'height': 407,
#   'width': 612,
#   'id': 'img_hod_001703',
#   'filename': 'img_hod_001703.jpg'},
#  {'file_name': 'img_hod_001829.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001829',
#   'filename': 'img_hod_001829.jpg'},
#  {'file_name': 'img_hod_001982.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001982',
#   'filename': 'img_hod_001982.jpg'},
#  {'file_name': 'img_hod_001981.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001981',
#   'filename': 'img_hod_001981.jpg'},
#  {'file_name': 'img_hod_001737.jpg',
#   'height': 612,
#   'width': 406,
#   'id': 'img_hod_001737',
#   'filename': 'img_hod_001737.jpg'},
#  {'file_name': 'img_hod_001930.jpg',
#   'height': 460,
#   'width': 612,
#   'id': 'img_hod_001930',
#   'filename': 'img_hod_001930.jpg'},
#  {'file_name': 'img_hod_001478.jpg',
#   'height': 612,
#   'width': 593,
#   'id': 'img_hod_001478',
#   'filename': 'img_hod_001478.jpg'},
#  {'file_name': 'img_hod_001501.jpg',
#   'height': 344,
#   'width': 612,
#   'id': 'img_hod_001501',
#   'filename': 'img_hod_001501.jpg'},
#  {'file_name': 'img_hod_001734.jpg',
#   'height': 511,
#   'width': 612,
#   'id': 'img_hod_001734',
#   'filename': 'img_hod_001734.jpg'},
#  {'file_name': 'img_hod_001742.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001742',
#   'filename': 'img_hod_001742.jpg'},
#  {'file_name': 'img_hod_001906.jpg',
#   'height': 612,
#   'width': 408,
#   'id': 'img_hod_001906',
#   'filename': 'img_hod_001906.jpg'},
#  {'file_name': 'img_hod_001701.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001701',
#   'filename': 'img_hod_001701.jpg'},
#  {'file_name': 'img_hod_001533.jpg',
#   'height': 395,
#   'width': 272,
#   'id': 'img_hod_001533',
#   'filename': 'img_hod_001533.jpg'},
#  {'file_name': 'img_hod_001487.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001487',
#   'filename': 'img_hod_001487.jpg'},
#  {'file_name': 'img_hod_001684.jpg',
#   'height': 407,
#   'width': 612,
#   'id': 'img_hod_001684',
#   'filename': 'img_hod_001684.jpg'},
#  {'file_name': 'img_hod_001669.jpg',
#   'height': 443,
#   'width': 612,
#   'id': 'img_hod_001669',
#   'filename': 'img_hod_001669.jpg'},
#  {'file_name': 'img_hod_009643.jpg',
#   'height': 626,
#   'width': 417,
#   'id': 'img_hod_009643',
#   'filename': 'img_hod_009643.jpg'},
#  {'file_name': 'img_hod_009688.jpg',
#   'height': 418,
#   'width': 626,
#   'id': 'img_hod_009688',
#   'filename': 'img_hod_009688.jpg'},
#  {'file_name': 'img_hod_001551.jpg',
#   'height': 301,
#   'width': 451,
#   'id': 'img_hod_001551',
#   'filename': 'img_hod_001551.jpg'},
#  {'file_name': 'img_hod_001651.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001651',
#   'filename': 'img_hod_001651.jpg'},
#  {'file_name': 'img_hod_001792.jpg',
#   'height': 612,
#   'width': 490,
#   'id': 'img_hod_001792',
#   'filename': 'img_hod_001792.jpg'},
#  {'file_name': 'img_hod_001719.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001719',
#   'filename': 'img_hod_001719.jpg'},
#  {'file_name': 'img_hod_002018.jpg',
#   'height': 317,
#   'width': 612,
#   'id': 'img_hod_002018',
#   'filename': 'img_hod_002018.jpg'},
#  {'file_name': 'img_hod_001763.jpg',
#   'height': 387,
#   'width': 612,
#   'id': 'img_hod_001763',
#   'filename': 'img_hod_001763.jpg'},
#  {'file_name': 'img_hod_002000.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002000',
#   'filename': 'img_hod_002000.jpg'},
#  {'file_name': 'img_hod_001667.jpg',
#   'height': 573,
#   'width': 612,
#   'id': 'img_hod_001667',
#   'filename': 'img_hod_001667.jpg'},
#  {'file_name': 'img_hod_002010.jpg',
#   'height': 612,
#   'width': 462,
#   'id': 'img_hod_002010',
#   'filename': 'img_hod_002010.jpg'},
#  {'file_name': 'img_hod_001936.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001936',
#   'filename': 'img_hod_001936.jpg'},
#  {'file_name': 'img_hod_001760.jpg',
#   'height': 413,
#   'width': 612,
#   'id': 'img_hod_001760',
#   'filename': 'img_hod_001760.jpg'},
#  {'file_name': 'img_hod_009636.jpg',
#   'height': 626,
#   'width': 418,
#   'id': 'img_hod_009636',
#   'filename': 'img_hod_009636.jpg'},
#  {'file_name': 'img_hod_001745.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001745',
#   'filename': 'img_hod_001745.jpg'},
#  {'file_name': 'img_hod_002017.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002017',
#   'filename': 'img_hod_002017.jpg'},
#  {'file_name': 'img_hod_001682.jpg',
#   'height': 612,
#   'width': 503,
#   'id': 'img_hod_001682',
#   'filename': 'img_hod_001682.jpg'},
#  {'file_name': 'img_hod_001827.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001827',
#   'filename': 'img_hod_001827.jpg'},
#  {'file_name': 'img_hod_001500.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001500',
#   'filename': 'img_hod_001500.jpg'},
#  {'file_name': 'img_hod_001516.jpg',
#   'height': 388,
#   'width': 445,
#   'id': 'img_hod_001516',
#   'filename': 'img_hod_001516.jpg'},
#  {'file_name': 'img_hod_001729.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001729',
#   'filename': 'img_hod_001729.jpg'},
#  {'file_name': 'img_hod_001631.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001631',
#   'filename': 'img_hod_001631.jpg'},
#  {'file_name': 'img_hod_001732.jpg',
#   'height': 407,
#   'width': 612,
#   'id': 'img_hod_001732',
#   'filename': 'img_hod_001732.jpg'},
#  {'file_name': 'img_hod_001498.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001498',
#   'filename': 'img_hod_001498.jpg'},
#  {'file_name': 'img_hod_001624.jpg',
#   'height': 612,
#   'width': 408,
#   'id': 'img_hod_001624',
#   'filename': 'img_hod_001624.jpg'},
#  {'file_name': 'img_hod_001680.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001680',
#   'filename': 'img_hod_001680.jpg'},
#  {'file_name': 'img_hod_010190.jpg',
#   'height': 4287,
#   'width': 6431,
#   'id': 'img_hod_010190',
#   'filename': 'img_hod_010190.jpg'},
#  {'file_name': 'img_hod_002029.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002029',
#   'filename': 'img_hod_002029.jpg'},
#  {'file_name': 'img_hod_001497.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001497',
#   'filename': 'img_hod_001497.jpg'},
#  {'file_name': 'img_hod_009713.jpg',
#   'height': 626,
#   'width': 417,
#   'id': 'img_hod_009713',
#   'filename': 'img_hod_009713.jpg'},
#  {'file_name': 'img_hod_001923.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001923',
#   'filename': 'img_hod_001923.jpg'},
#  {'file_name': 'img_hod_002034.jpg',
#   'height': 489,
#   'width': 612,
#   'id': 'img_hod_002034',
#   'filename': 'img_hod_002034.jpg'},
#  {'file_name': 'img_hod_001511.jpg',
#   'height': 433,
#   'width': 367,
#   'id': 'img_hod_001511',
#   'filename': 'img_hod_001511.jpg'},
#  {'file_name': 'img_hod_001924.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001924',
#   'filename': 'img_hod_001924.jpg'},
#  {'file_name': 'img_hod_001642.jpg',
#   'height': 397,
#   'width': 612,
#   'id': 'img_hod_001642',
#   'filename': 'img_hod_001642.jpg'},
#  {'file_name': 'img_hod_001838.jpg',
#   'height': 527,
#   'width': 612,
#   'id': 'img_hod_001838',
#   'filename': 'img_hod_001838.jpg'},
#  {'file_name': 'img_hod_001674.jpg',
#   'height': 612,
#   'width': 420,
#   'id': 'img_hod_001674',
#   'filename': 'img_hod_001674.jpg'},
#  {'file_name': 'img_hod_001499.jpg',
#   'height': 612,
#   'width': 408,
#   'id': 'img_hod_001499',
#   'filename': 'img_hod_001499.jpg'},
#  {'file_name': 'img_hod_002014.jpg',
#   'height': 441,
#   'width': 612,
#   'id': 'img_hod_002014',
#   'filename': 'img_hod_002014.jpg'},
#  {'file_name': 'img_hod_001852.jpg',
#   'height': 346,
#   'width': 612,
#   'id': 'img_hod_001852',
#   'filename': 'img_hod_001852.jpg'},
#  {'file_name': 'img_hod_001466.jpg',
#   'height': 344,
#   'width': 612,
#   'id': 'img_hod_001466',
#   'filename': 'img_hod_001466.jpg'},
#  {'file_name': 'img_hod_001961.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001961',
#   'filename': 'img_hod_001961.jpg'},
#  {'file_name': 'img_hod_001799.jpg',
#   'height': 407,
#   'width': 612,
#   'id': 'img_hod_001799',
#   'filename': 'img_hod_001799.jpg'},
#  {'file_name': 'img_hod_001695.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001695',
#   'filename': 'img_hod_001695.jpg'},
#  {'file_name': 'img_hod_002006.jpg',
#   'height': 356,
#   'width': 612,
#   'id': 'img_hod_002006',
#   'filename': 'img_hod_002006.jpg'},
#  {'file_name': 'img_hod_001515.jpg',
#   'height': 329,
#   'width': 420,
#   'id': 'img_hod_001515',
#   'filename': 'img_hod_001515.jpg'},
#  {'file_name': 'img_hod_009645.jpg',
#   'height': 542,
#   'width': 626,
#   'id': 'img_hod_009645',
#   'filename': 'img_hod_009645.jpg'},
#  {'file_name': 'img_hod_001814.jpg',
#   'height': 534,
#   'width': 612,
#   'id': 'img_hod_001814',
#   'filename': 'img_hod_001814.jpg'},
#  {'file_name': 'img_hod_001594.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_001594',
# ...
#  {'file_name': 'img_hod_007207.jpg',
#   'height': 612,
#   'width': 408,
#   'id': 'img_hod_007207',
#   'filename': 'img_hod_007207.jpg'},
#  {'file_name': 'img_hod_007204.jpg',
#   'height': 612,
#   'width': 473,
#   'id': 'img_hod_007204',
#   'filename': 'img_hod_007204.jpg'},
#  {'file_name': 'img_hod_008463.jpg',
#   'height': 853,
#   'width': 1280,
#   'id': 'img_hod_008463',
#   'filename': 'img_hod_008463.jpg'},
#  {'file_name': 'img_hod_006660.jpg',
#   'height': 333,
#   'width': 500,
#   'id': 'img_hod_006660',
#   'filename': 'img_hod_006660.jpg'},
#  {'file_name': 'img_hod_006816.jpg',
#   'height': 333,
#   'width': 500,
#   'id': 'img_hod_006816',
#   'filename': 'img_hod_006816.jpg'},
#  {'file_name': 'img_hod_006629.jpg',
#   'height': 749,
#   'width': 500,
#   'id': 'img_hod_006629',
#   'filename': 'img_hod_006629.jpg'},
#  {'file_name': 'img_hod_010363.jpg',
#   'height': 557,
#   'width': 474,
#   'id': 'img_hod_010363',
#   'filename': 'img_hod_010363.jpg'},
#  {'file_name': 'img_hod_008334.jpg',
#   'height': 1280,
#   'width': 720,
#   'id': 'img_hod_008334',
#   'filename': 'img_hod_008334.jpg'},
#  {'file_name': 'img_hod_006831.jpg',
#   'height': 333,
#   'width': 500,
#   'id': 'img_hod_006831',
#   'filename': 'img_hod_006831.jpg'},
#  {'file_name': 'img_hod_007147.jpg',
#   'height': 612,
#   'width': 408,
#   'id': 'img_hod_007147',
#   'filename': 'img_hod_007147.jpg'},
#  {'file_name': 'img_hod_007026.jpg',
#   'height': 750,
#   'width': 500,
#   'id': 'img_hod_007026',
#   'filename': 'img_hod_007026.jpg'},
#  {'file_name': 'img_hod_009024.jpg',
#   'height': 417,
#   'width': 626,
#   'id': 'img_hod_009024',
#   'filename': 'img_hod_009024.jpg'},
#  {'file_name': 'img_hod_002161.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002161',
#   'filename': 'img_hod_002161.jpg'},
#  {'file_name': 'img_hod_002337.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002337',
#   'filename': 'img_hod_002337.jpg'},
#  {'file_name': 'img_hod_007816.jpg',
#   'height': 612,
#   'width': 510,
#   'id': 'img_hod_007816',
#   'filename': 'img_hod_007816.jpg'},
#  {'file_name': 'img_hod_006541.jpg',
#   'height': 750,
#   'width': 500,
#   'id': 'img_hod_006541',
#   'filename': 'img_hod_006541.jpg'},
#  {'file_name': 'img_hod_007105.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_007105',
#   'filename': 'img_hod_007105.jpg'},
#  {'file_name': 'img_hod_006371.jpg',
#   'height': 748,
#   'width': 500,
#   'id': 'img_hod_006371',
#   'filename': 'img_hod_006371.jpg'},
#  {'file_name': 'img_hod_008435.jpg',
#   'height': 853,
#   'width': 1280,
#   'id': 'img_hod_008435',
#   'filename': 'img_hod_008435.jpg'},
#  {'file_name': 'img_hod_010466.jpg',
#   'height': 474,
#   'width': 474,
#   'id': 'img_hod_010466',
#   'filename': 'img_hod_010466.jpg'},
#  {'file_name': 'img_hod_002173.jpg',
#   'height': 612,
#   'width': 408,
#   'id': 'img_hod_002173',
#   'filename': 'img_hod_002173.jpg'},
#  {'file_name': 'img_hod_008352.jpg',
#   'height': 816,
#   'width': 1280,
#   'id': 'img_hod_008352',
#   'filename': 'img_hod_008352.jpg'},
#  {'file_name': 'img_hod_002506.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002506',
#   'filename': 'img_hod_002506.jpg'},
#  {'file_name': 'img_hod_006575.jpg',
#   'height': 750,
#   'width': 500,
#   'id': 'img_hod_006575',
#   'filename': 'img_hod_006575.jpg'},
#  {'file_name': 'img_hod_008269.jpg',
#   'height': 328,
#   'width': 526,
#   'id': 'img_hod_008269',
#   'filename': 'img_hod_008269.jpg'},
#  {'file_name': 'img_hod_002632.jpg',
#   'height': 459,
#   'width': 612,
#   'id': 'img_hod_002632',
#   'filename': 'img_hod_002632.jpg'},
#  {'file_name': 'img_hod_007716.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_007716',
#   'filename': 'img_hod_007716.jpg'},
#  {'file_name': 'img_hod_002200.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002200',
#   'filename': 'img_hod_002200.jpg'},
#  {'file_name': 'img_hod_008017.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_008017',
#   'filename': 'img_hod_008017.jpg'},
#  {'file_name': 'img_hod_006684.jpg',
#   'height': 750,
#   'width': 500,
#   'id': 'img_hod_006684',
#   'filename': 'img_hod_006684.jpg'},
#  {'file_name': 'img_hod_006775.jpg',
#   'height': 750,
#   'width': 500,
#   'id': 'img_hod_006775',
#   'filename': 'img_hod_006775.jpg'},
#  {'file_name': 'img_hod_007249.jpg',
#   'height': 407,
#   'width': 612,
#   'id': 'img_hod_007249',
#   'filename': 'img_hod_007249.jpg'},
#  {'file_name': 'img_hod_002134.jpg',
#   'height': 530,
#   'width': 612,
#   'id': 'img_hod_002134',
#   'filename': 'img_hod_002134.jpg'},
#  {'file_name': 'img_hod_006388.jpg',
#   'height': 338,
#   'width': 500,
#   'id': 'img_hod_006388',
#   'filename': 'img_hod_006388.jpg'},
#  {'file_name': 'img_hod_007335.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_007335',
#   'filename': 'img_hod_007335.jpg'},
#  {'file_name': 'img_hod_008998.jpg',
#   'height': 417,
#   'width': 626,
#   'id': 'img_hod_008998',
#   'filename': 'img_hod_008998.jpg'},
#  {'file_name': 'img_hod_002596.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002596',
#   'filename': 'img_hod_002596.jpg'},
#  {'file_name': 'img_hod_006570.jpg',
#   'height': 333,
#   'width': 500,
#   'id': 'img_hod_006570',
#   'filename': 'img_hod_006570.jpg'},
#  {'file_name': 'img_hod_007503.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_007503',
#   'filename': 'img_hod_007503.jpg'},
#  {'file_name': 'img_hod_007264.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_007264',
#   'filename': 'img_hod_007264.jpg'},
#  {'file_name': 'img_hod_007465.jpg',
#   'height': 407,
#   'width': 612,
#   'id': 'img_hod_007465',
#   'filename': 'img_hod_007465.jpg'},
#  {'file_name': 'img_hod_007751.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_007751',
#   'filename': 'img_hod_007751.jpg'},
#  {'file_name': 'img_hod_002417.jpg',
#   'height': 407,
#   'width': 612,
#   'id': 'img_hod_002417',
#   'filename': 'img_hod_002417.jpg'},
#  {'file_name': 'img_hod_006568.jpg',
#   'height': 274,
#   'width': 500,
#   'id': 'img_hod_006568',
#   'filename': 'img_hod_006568.jpg'},
#  {'file_name': 'img_hod_010513.jpg',
#   'height': 474,
#   'width': 474,
#   'id': 'img_hod_010513',
#   'filename': 'img_hod_010513.jpg'},
#  {'file_name': 'img_hod_008277.jpg',
#   'height': 1280,
#   'width': 966,
#   'id': 'img_hod_008277',
#   'filename': 'img_hod_008277.jpg'},
#  {'file_name': 'img_hod_006807.jpg',
#   'height': 375,
#   'width': 500,
#   'id': 'img_hod_006807',
#   'filename': 'img_hod_006807.jpg'},
#  {'file_name': 'img_hod_002528.jpg',
#   'height': 612,
#   'width': 408,
#   'id': 'img_hod_002528',
#   'filename': 'img_hod_002528.jpg'},
#  {'file_name': 'img_hod_006370.jpg',
#   'height': 750,
#   'width': 500,
#   'id': 'img_hod_006370',
#   'filename': 'img_hod_006370.jpg'},
#  {'file_name': 'img_hod_006824.jpg',
#   'height': 333,
#   'width': 500,
#   'id': 'img_hod_006824',
#   'filename': 'img_hod_006824.jpg'},
#  {'file_name': 'img_hod_002656.jpg',
#   'height': 459,
#   'width': 612,
#   'id': 'img_hod_002656',
#   'filename': 'img_hod_002656.jpg'},
#  {'file_name': 'img_hod_006934.jpg',
#   'height': 750,
#   'width': 500,
#   'id': 'img_hod_006934',
#   'filename': 'img_hod_006934.jpg'},
#  {'file_name': 'img_hod_007126.jpg',
#   'height': 612,
#   'width': 468,
#   'id': 'img_hod_007126',
#   'filename': 'img_hod_007126.jpg'},
#  {'file_name': 'img_hod_008022.jpg',
#   'height': 344,
#   'width': 612,
#   'id': 'img_hod_008022',
#   'filename': 'img_hod_008022.jpg'},
#  {'file_name': 'img_hod_007781.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_007781',
#   'filename': 'img_hod_007781.jpg'},
#  {'file_name': 'img_hod_002648.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002648',
#   'filename': 'img_hod_002648.jpg'},
#  {'file_name': 'img_hod_002094.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002094',
#   'filename': 'img_hod_002094.jpg'},
#  {'file_name': 'img_hod_002575.jpg',
#   'height': 459,
#   'width': 612,
#   'id': 'img_hod_002575',
#   'filename': 'img_hod_002575.jpg'},
#  {'file_name': 'img_hod_008445.jpg',
#   'height': 853,
#   'width': 1280,
#   'id': 'img_hod_008445',
#   'filename': 'img_hod_008445.jpg'},
#  {'file_name': 'img_hod_010553.jpg',
#   'height': 472,
#   'width': 474,
#   'id': 'img_hod_010553',
#   'filename': 'img_hod_010553.jpg'},
#  {'file_name': 'img_hod_002402.jpg',
#   'height': 405,
#   'width': 612,
#   'id': 'img_hod_002402',
#   'filename': 'img_hod_002402.jpg'},
#  {'file_name': 'img_hod_002262.jpg',
#   'height': 397,
#   'width': 612,
#   'id': 'img_hod_002262',
#   'filename': 'img_hod_002262.jpg'},
#  {'file_name': 'img_hod_002098.jpg',
#   'height': 612,
#   'width': 411,
#   'id': 'img_hod_002098',
#   'filename': 'img_hod_002098.jpg'},
#  {'file_name': 'img_hod_006277.jpg',
#   'height': 750,
#   'width': 500,
#   'id': 'img_hod_006277',
#   'filename': 'img_hod_006277.jpg'},
#  {'file_name': 'img_hod_004241.jpg',
#   'height': 1280,
#   'width': 1280,
#   'id': 'img_hod_004241',
#   'filename': 'img_hod_004241.jpg'},
#  {'file_name': 'img_hod_007402.jpg',
#   'height': 612,
#   'width': 612,
#   'id': 'img_hod_007402',
#   'filename': 'img_hod_007402.jpg'},
#  {'file_name': 'img_hod_007480.jpg',
#   'height': 344,
#   'width': 612,
#   'id': 'img_hod_007480',
#   'filename': 'img_hod_007480.jpg'},
#  {'file_name': 'img_hod_002067.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002067',
#   'filename': 'img_hod_002067.jpg'},
#  {'file_name': 'img_hod_006632.jpg',
#   'height': 749,
#   'width': 500,
#   'id': 'img_hod_006632',
#   'filename': 'img_hod_006632.jpg'},
#  {'file_name': 'img_hod_006885.jpg',
#   'height': 334,
#   'width': 500,
#   'id': 'img_hod_006885',
#   'filename': 'img_hod_006885.jpg'},
#  {'file_name': 'img_hod_009098.jpg',
#   'height': 417,
#   'width': 626,
#   'id': 'img_hod_009098',
#   'filename': 'img_hod_009098.jpg'},
#  {'file_name': 'img_hod_007342.jpg',
#   'height': 463,
#   'width': 612,
#   'id': 'img_hod_007342',
#   'filename': 'img_hod_007342.jpg'},
#  {'file_name': 'img_hod_010334.jpg',
#   'height': 396,
#   'width': 474,
#   'id': 'img_hod_010334',
#   'filename': 'img_hod_010334.jpg'},
#  {'file_name': 'img_hod_010433.jpg',
#   'height': 543,
#   'width': 474,
#   'id': 'img_hod_010433',
#   'filename': 'img_hod_010433.jpg'},
#  {'file_name': 'img_hod_006672.jpg',
#   'height': 750,
#   'width': 500,
#   'id': 'img_hod_006672',
#   'filename': 'img_hod_006672.jpg'},
#  {'file_name': 'img_hod_007221.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_007221',
#   'filename': 'img_hod_007221.jpg'},
#  {'file_name': 'img_hod_007141.jpg',
#   'height': 421,
#   'width': 612,
#   'id': 'img_hod_007141',
#   'filename': 'img_hod_007141.jpg'},
#  {'file_name': 'img_hod_002203.jpg',
#   'height': 612,
#   'width': 408,
#   'id': 'img_hod_002203',
#   'filename': 'img_hod_002203.jpg'},
#  {'file_name': 'img_hod_010133.jpg',
#   'height': 1066,
#   'width': 1599,
#   'id': 'img_hod_010133',
#   'filename': 'img_hod_010133.jpg'},
#  {'file_name': 'img_hod_002111.jpg',
#   'height': 405,
#   'width': 612,
#   'id': 'img_hod_002111',
#   'filename': 'img_hod_002111.jpg'},
#  {'file_name': 'img_hod_002504.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002504',
#   'filename': 'img_hod_002504.jpg'},
#  {'file_name': 'img_hod_007302.jpg',
#   'height': 404,
#   'width': 612,
#   'id': 'img_hod_007302',
#   'filename': 'img_hod_007302.jpg'},
#  {'file_name': 'img_hod_006384.jpg',
#   'height': 625,
#   'width': 500,
#   'id': 'img_hod_006384',
#   'filename': 'img_hod_006384.jpg'},
#  {'file_name': 'img_hod_002395.jpg',
#   'height': 405,
#   'width': 612,
#   'id': 'img_hod_002395',
#   'filename': 'img_hod_002395.jpg'},
#  {'file_name': 'img_hod_002090.jpg',
#   'height': 612,
#   'width': 612,
#   'id': 'img_hod_002090',
#   'filename': 'img_hod_002090.jpg'},
#  {'file_name': 'img_hod_007410.jpg',
#   'height': 405,
#   'width': 612,
#   'id': 'img_hod_007410',
#   'filename': 'img_hod_007410.jpg'},
#  {'file_name': 'img_hod_007550.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_007550',
#   'filename': 'img_hod_007550.jpg'},
#  {'file_name': 'img_hod_008353.jpg',
#   'height': 853,
#   'width': 1280,
#   'id': 'img_hod_008353',
#   'filename': 'img_hod_008353.jpg'},
#  {'file_name': 'img_hod_006533.jpg',
#   'height': 750,
#   'width': 500,
#   'id': 'img_hod_006533',
#   'filename': 'img_hod_006533.jpg'},
#  {'file_name': 'img_hod_002306.jpg',
#   'height': 409,
#   'width': 612,
#   'id': 'img_hod_002306',
#   'filename': 'img_hod_002306.jpg'},
#  {'file_name': 'img_hod_002342.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002342',
#   'filename': 'img_hod_002342.jpg'},
#  {'file_name': 'img_hod_006618.jpg',
#   'height': 750,
#   'width': 500,
#   'id': 'img_hod_006618',
#   'filename': 'img_hod_006618.jpg'},
#  {'file_name': 'img_hod_010571.jpg',
#   'height': 474,
#   'width': 474,
#   'id': 'img_hod_010571',
#   'filename': 'img_hod_010571.jpg'},
#  {'file_name': 'img_hod_002208.jpg',
#   'height': 612,
#   'width': 408,
#   'id': 'img_hod_002208',
#   'filename': 'img_hod_002208.jpg'},
#  {'file_name': 'img_hod_007582.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_007582',
#   'filename': 'img_hod_007582.jpg'},
#  {'file_name': 'img_hod_004233.jpg',
#   'height': 640,
#   'width': 1280,
#   'id': 'img_hod_004233',
#   'filename': 'img_hod_004233.jpg'},
#  {'file_name': 'img_hod_007475.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_007475',
#   'filename': 'img_hod_007475.jpg'},
#  {'file_name': 'img_hod_004257.jpg',
#   'height': 1280,
#   'width': 640,
#   'id': 'img_hod_004257',
#   'filename': 'img_hod_004257.jpg'},
#  {'file_name': 'img_hod_002657.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002657',
#   'filename': 'img_hod_002657.jpg'},
#  {'file_name': 'img_hod_002594.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002594',
#   'filename': 'img_hod_002594.jpg'},
#  {'file_name': 'img_hod_002060.jpg',
#   'height': 406,
#   'width': 612,
#   'id': 'img_hod_002060',
#   'filename': 'img_hod_002060.jpg'},
#  {'file_name': 'img_hod_002246.jpg',
#   'height': 612,
#   'width': 364,
#   'id': 'img_hod_002246',
#   'filename': 'img_hod_002246.jpg'},
#  {'file_name': 'img_hod_002544.jpg',
#   'height': 405,
#   'width': 612,
#   'id': 'img_hod_002544',
#   'filename': 'img_hod_002544.jpg'},
#  {'file_name': 'img_hod_002410.jpg',
#   'height': 408,
#   'width': 612,
#   'id': 'img_hod_002410',
#   'filename': 'img_hod_002410.jpg'},
#  {'file_name': 'img_hod_002312.jpg',
#   'height': 409,
#   'width': 612,
#   'id': 'img_hod_002312',
#   'filename': 'img_hod_002312.jpg'},
#  {'file_name': 'img_hod_004216.jpg',
#   'height': 1102,
#   'width': 1280,
#   'id': 'img_hod_004216',
#   'filename': 'img_hod_004216.jpg'},
#  {'file_name': 'img_hod_007363.jpg',
#   'height': 612,
#   'width': 612,
#   'id': 'img_hod_007363',
#   'filename': 'img_hod_007363.jpg'},
#  {'file_name': 'img_hod_006795.jpg',
#   'height': 333,
#   'width': 500,
#   'id': 'img_hod_006795',
#   'filename': 'img_hod_006795.jpg'},
#  {'file_name': 'img_hod_007840.jpg',
#   'height': 345,
#   'width': 612,
#   'id': 'img_hod_007840',
#   'filename': 'img_hod_007840.jpg'},
#  {'file_name': 'img_hod_004259.jpg',
#   'height': 1280,
#   'width': 817,
#   'id': 'img_hod_004259',
#   'filename': 'img_hod_004259.jpg'},
#  {'file_name': 'img_hod_008387.jpg',
#   'height': 853,
#   'width': 1280,
#   'id': 'img_hod_008387',
#   'filename': 'img_hod_008387.jpg'},
#  {'file_name': 'img_hod_010395.jpg',
#   'height': 441,
#   'width': 474,
#   'id': 'img_hod_010395',
#   'filename': 'img_hod_010395.jpg'},
#  {'file_name': 'img_hod_002355.jpg',
#   'height': 503,
#   'width': 612,
#   'id': 'img_hod_002355',
#   'filename': 'img_hod_002355.jpg'},
#  {'file_name': 'img_hod_006550.jpg',
#   'height': 750,
#   'width': 500,
#   'id': 'img_hod_006550',
#   'filename': 'img_hod_006550.jpg'},
#  {'file_name': 'img_hod_002141.jpg',
#   'height': 268,
#   'width': 612,
#   'id': 'img_hod_002141',
#   'filename': 'img_hod_002141.jpg'},
#  {'file_name': 'img_hod_004255.jpg',
#   'height': 1280,
#   'width': 1280,
#   'id': 'img_hod_004255',
#   'filename': 'img_hod_004255.jpg'},
#  {'file_name': 'img_hod_009165.jpg',
#   'height': 441,
#   'width': 626,
#   'id': 'img_hod_009165',
#   'filename': 'img_hod_009165.jpg'},
#  {'file_name': 'img_hod_007149.jpg',
#   'height': 428,
#   'width': 612,
#   'id': 'img_hod_007149',
#   'filename': 'img_hod_007149.jpg'},
#  {'file_name': 'img_hod_006389.jpg',
#   'height': 331,
#   'width': 500,
#   'id': 'img_hod_006389',
#   'filename': 'img_hod_006389.jpg'},
#  {'file_name': 'img_hod_007689.jpg',
#   'height': 612,
#   'width': 407,
#   'id': 'img_hod_007689',
#   'filename': 'img_hod_007689.jpg'},
#  ...]

# %%
datasets[0].pipeline
# Out:
# Compose(
#     LoadImageFromFile(to_float32=False, color_type='color', channel_order='bgr', file_client_args={'backend': 'disk'})
#     LoadAnnotations(with_bbox=True, with_label=True, with_mask=False, with_seg=False, poly2mask=True, file_client_args={'backend': 'disk'})
#     Resize(img_scale=[(1333, 800)], multiscale_mode=range, ratio_range=None, keep_ratio=True, bbox_clip_border=True)
#     RandomFlip(flip_ratio=0.5)
#     Normalize(mean=[123.675 116.28  103.53 ], std=[58.395 57.12  57.375], to_rgb=True)
#     Pad(size=None, size_divisor=32, pad_to_square=False, pad_val={'img': 0, 'masks': 0, 'seg': 255})
#     DefaultFormatBundle(img_to_float=True)
#     Collect(keys=['img', 'gt_bboxes', 'gt_labels'], meta_keys=('filename', 'ori_filename', 'ori_shape', 'img_shape', 'pad_shape', 'scale_factor', 'flip', 'flip_direction', 'img_norm_cfg'))
# )

# %%
model = build_detector(cfg.model, train_cfg=cfg.get('train_cfg'), test_cfg=cfg.get('test_cfg'))
model.CLASSES = datasets[0].CLASSES
print(model.CLASSES)
# Out:
# ('alcohol', 'insulting_gesture', 'blood', 'cigarette', 'gun', 'knife')

# %%
import os.path as osp
mmcv.mkdir_or_exist(osp.abspath(cfg.work_dir))
train_detector(model, datasets, cfg, distributed=False, validate=True)
# Out:
# 2023-10-12 23:07:08,355 - mmdet - INFO - Automatic scaling of learning rate (LR) has been disabled.
# 2023-10-12 23:07:08,365 - mmdet - INFO - load checkpoint from local path: ./mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth
# 2023-10-12 23:07:08,493 - mmdet - WARNING - The model and loaded state dict do not match exactly
#
# size mismatch for roi_head.bbox_head.fc_cls.weight: copying a param with shape torch.Size([81, 1024]) from checkpoint, the shape in current model is torch.Size([7, 1024]).
# size mismatch for roi_head.bbox_head.fc_cls.bias: copying a param with shape torch.Size([81]) from checkpoint, the shape in current model is torch.Size([7]).
# size mismatch for roi_head.bbox_head.fc_reg.weight: copying a param with shape torch.Size([320, 1024]) from checkpoint, the shape in current model is torch.Size([24, 1024]).
# size mismatch for roi_head.bbox_head.fc_reg.bias: copying a param with shape torch.Size([320]) from checkpoint, the shape in current model is torch.Size([24]).
# 2023-10-12 23:07:08,501 - mmdet - INFO - Start running, host: oks@smart3, work_dir: /home/oks/people/egha/tutorial_exps_normal
# 2023-10-12 23:07:08,502 - mmdet - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) StepLrUpdaterHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) StepLrUpdaterHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
#  --------------------
# after_train_iter:
# (ABOVE_NORMAL) OptimizerHook
# (NORMAL      ) CheckpointHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# (NORMAL      ) SaveBestCheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_epoch:
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_run:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# 2023-10-12 23:07:08,504 - mmdet - INFO - workflow: [('train', 1)], max: 1 epochs
# 2023-10-12 23:07:08,505 - mmdet - INFO - Checkpoints will be saved to /home/oks/people/egha/tutorial_exps_normal by HardDiskBackend.
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 2023-10-12 23:17:32,837 - mmdet - INFO - Epoch [1][2000/2324]	lr: 2.500e-03, eta: 0:01:41, time: 0.312, data_time: 0.007, memory: 3778, loss_rpn_cls: 0.0072, loss_rpn_bbox: 0.0133, loss_cls: 0.0851, acc: 97.4375, loss_bbox: 0.0805, loss: 0.1861
# 2023-10-12 23:19:13,310 - mmdet - INFO - Saving checkpoint at 1 epochs

# %%
# !pwd
# Out:
# /home/oks/people/egha

# %% [markdown]
# ### Inference and Result Visualization
# #### Paper Section: 4.3 Testing Procedure

# %%
import cv2
from mmdet.apis import inference_detector, init_detector, show_result_pyplot

# Loading a sample image for inference
img = cv2.imread('./faster_rcnn_data/rcnn_normal/JPEGImages/img_hod_001544.jpg')

# Setting the configuration for the model
model.cfg = cfg

# Performing inference on the sample image
result = inference_detector(model, img)

# Visualizing the inference results
show_result_pyplot(model, img, result)

# %% [markdown]
# #### This marks the end of code snippet for training a Faster-RCNN model on the HOD dataset for normal cases.
